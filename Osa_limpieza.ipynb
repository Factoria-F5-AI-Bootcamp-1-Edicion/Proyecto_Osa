# %% [markdown]
# # Inteligencia de Negocio en Supermercado Cooperativo La Osa

# %% [markdown]
# # Análisis Exploratorio

# %%
# Cargar librerías
import pandas as pd
import seaborn as sn
import numpy as np
import matplotlib as ploty

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
### Importamos los datasets
# Datasets de compra de productos a proveedores 2021-2022
precio_enejun= pd.read_excel("Evolución_precio_enerojunio22.xls")
precio_juldic= pd.read_excel("Evolución_precio_juliodiciembre22.xls") # Obs. columna mes diciembre se encuenra con datos similares en precio_2022
precio_2021= pd.read_excel("Price_history_2021.xls")
precio_2022= pd.read_excel("Price_history_122022.xls")  # Una sóla columna aparentemente similar a dic de precio_juldic

#Datasets de venta de productos al publico 2021-2022
ventas_2021= pd.read_excel("Ventas_PVP_inflación_2021.xls")
ventas_2022= pd.read_excel("Ventas_PVP_inflación_2022.xls")

# %%
# 1. Analizando el dataframe: precio_enejun
# Visualizar información básica del dataframe precio_enejun
precio_enejun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33361 entries, 0 to 33360
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             21005 non-null  object
#  1   Producto/Nombre                                         21005 non-null  object
#  2   Coste                                                   21005 non-null  float64
#  3   Fecha                                                   21005 non-null  datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  21005 non-null  object
#  5   Producto/Referencia interna                             21005 non-null  float64
#  6   Producto/Proveedores/Nombre a mostrar                   33361 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         21005 non-null  object
# ...

# %%
precio_enejun
# Out:
#                                            External ID  \
# 0      __export__.product_price_history_78926_abded360
# 1      __export__.product_price_history_78925_30713b35
# 2      __export__.product_price_history_78916_73aa1b21
# 3      __export__.product_price_history_78919_197ec6c0
# 4      __export__.product_price_history_78918_c43ac4cb
# ...                                                ...
# 33356  __export__.product_price_history_57476_a123a605
# 33357  __export__.product_price_history_57475_01d2b4c1
# 33358  __export__.product_price_history_57473_9223a116
# 33359  __export__.product_price_history_57474_6d53100b
# 33360  __export__.product_price_history_57472_e1e9d62e
#
#                                          Producto/Nombre  Coste  \
# 0                                       Envase Veer 33cl   0.15
# 1                                       Envase Veer 33cl   0.15
# 2                          Fuet extra Biobardales 200 gr   2.95
# ...

# %%
# 2. Analizando el dataframe: precio_juldic
# Visualizar información básica del dataframe precio_juldic
precio_juldic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             16217 non-null  object
#  1   Producto/Nombre                                         16217 non-null  object
#  2   Coste                                                   16217 non-null  float64
#  3   Fecha                                                   16217 non-null  datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  16217 non-null  object
#  5   Producto/Referencia interna                             16217 non-null  float64
#  6   Producto/Proveedores/Nombre a mostrar                   24783 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         16217 non-null  object
# ...

# %%
precio_juldic
# Out:
#                                            External ID  \
# 0      __export__.product_price_history_95321_35282e65
# 1      __export__.product_price_history_95315_6718a328
# 2      __export__.product_price_history_95314_e5481612
# 3      __export__.product_price_history_95313_1e7ac49b
# 4      __export__.product_price_history_95312_1fbab516
# ...                                                ...
# 24778  __export__.product_price_history_78928_ebc91b42
# 24779                                              NaN
# 24780                                              NaN
# 24781                                              NaN
# 24782  __export__.product_price_history_78927_9cdb8c96
#
#                                    Producto/Nombre  Coste               Fecha  \
# 0                Barrita de sésamo bio Ideas 20 gr   0.26 2022-12-14 12:37:50
# 1         Crema de cacahuete bio Ethiquable 350 gr   3.63 2022-12-14 12:37:50
# ...

# %%
# 3. Analizando el dataframe: precio_2021
# Visualizar información básica del dataframe precio_2021
precio_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57558 entries, 0 to 57557
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             37023 non-null  object
#  1   Producto/Nombre                                         37023 non-null  object
#  2   Coste                                                   37023 non-null  float64
#  3   Fecha                                                   37023 non-null  datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  37023 non-null  object
#  5   Producto/Referencia interna                             37023 non-null  float64
#  6   Producto/Proveedores/Nombre a mostrar                   57558 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         37023 non-null  object
# ...

# %%
precio_2021
# Out:
#                                            External ID  \
# 0      __export__.product_price_history_57358_1e54992d
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 57553  __export__.product_price_history_17321_030fc96e
# 57554  __export__.product_price_history_17319_e9e33a8c
# 57555  __export__.product_price_history_17317_607ad568
# 57556  __export__.product_price_history_17316_a7765be4
# 57557  __export__.product_price_history_17315_175465d1
#
#                                        Producto/Nombre  Coste  \
# 0                                   Manzana royal gala   1.53
# 1                                                  NaN    NaN
# 2                                                  NaN    NaN
# ...

# %%
# 4. Analizando el dataframe: precio_2022
# Visualizar información básica del dataframe precio_2022
precio_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4254 entries, 0 to 4253
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             2809 non-null   object
#  1   Producto/Nombre                                         2809 non-null   object
#  2   Coste                                                   2809 non-null   float64
#  3   Fecha                                                   2809 non-null   datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  2809 non-null   object
#  5   Producto/Referencia interna                             2809 non-null   float64
#  6   Producto/Proveedores/Nombre a mostrar                   4254 non-null   object
#  7   Producto/Categoría de producto/Nombre a mostrar         2809 non-null   object
# ...

# %%
precio_2022
# Out:
#                                           External ID  \
# 0     __export__.product_price_history_96984_4bf1bf39
# 1                                                 NaN
# 2     __export__.product_price_history_96985_0c0a24a8
# 3                                                 NaN
# 4     __export__.product_price_history_96965_065bfbca
# ...                                               ...
# 4249                                              NaN
# 4250                                              NaN
# 4251  __export__.product_price_history_94161_7fe055d2
# 4252                                              NaN
# 4253                                              NaN
#
#                                         Producto/Nombre  Coste  \
# 0     Yogur desnatado vainilla Casa grande xanceda 2...   1.45
# 1                                                   NaN    NaN
# 2     Queso eco peregrino producción limitada Casa G...   7.70
# ...

# %%
# 5. Analizando el dataframe: ventas_2021
# Visualizar información básica del dataframe ventas_2021
ventas_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3879 entries, 0 to 3878
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3877 non-null   object
#  1   Total        1907 non-null   object
#  2   Unnamed: 2   1906 non-null   object
#  3   Unnamed: 3   2067 non-null   object
#  4   Unnamed: 4   2066 non-null   object
#  5   Unnamed: 5   2251 non-null   object
#  6   Unnamed: 6   2250 non-null   object
#  7   Unnamed: 7   2327 non-null   object
#  8   Unnamed: 8   2326 non-null   object
#  9   Unnamed: 9   2381 non-null   object
#  10  Unnamed: 10  2380 non-null   object
#  11  Unnamed: 11  2485 non-null   object
#  12  Unnamed: 12  2484 non-null   object
#  13  Unnamed: 13  2465 non-null   object
#  14  Unnamed: 14  2464 non-null   object
#  15  Unnamed: 15  2264 non-null   object
#  16  Unnamed: 16  2263 non-null   object
#  17  Unnamed: 17  2542 non-null   object
# ...

# %%
ventas_2021
# Out:
#                                              Unnamed: 0              Total  \
# 0                                                   NaN         enero 2021
# 1                                                   NaN  Cantidad producto
# 2                                                 Total           22238.75
# 3          [000007] Aceite árnica y romero Piel sana...                NaN
# 4          [000008] Aceite caléndula y almendras Pie...                  2
# ...                                                 ...                ...
# 3874       [006160] Yogur de soja con limón Sojade 4...                  4
# 3875       [006161] Yogur de soja con plátano y mara...                  5
# 3876        [006162] Yogur de soja natural Sojade 400 g                 12
# 3877       [006163] Yogur de soja natural Sojade 4 x...                 13
# 3878       [006164] Yogur de soja quark griego Sojad...                  6
#
# ...

# %%
# 6. Analizando el dataframe: ventas_2022
# Visualizar información básica del dataframe ventas_2022
ventas_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3937 entries, 0 to 3936
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3935 non-null   object
#  1   Total        2723 non-null   object
#  2   Unnamed: 2   2722 non-null   object
#  3   Unnamed: 3   2662 non-null   object
#  4   Unnamed: 4   2661 non-null   object
#  5   Unnamed: 5   2750 non-null   object
#  6   Unnamed: 6   2749 non-null   object
#  7   Unnamed: 7   2741 non-null   object
#  8   Unnamed: 8   2740 non-null   object
#  9   Unnamed: 9   2668 non-null   object
#  10  Unnamed: 10  2667 non-null   object
#  11  Unnamed: 11  2605 non-null   object
#  12  Unnamed: 12  2604 non-null   object
#  13  Unnamed: 13  2526 non-null   object
#  14  Unnamed: 14  2525 non-null   object
#  15  Unnamed: 15  2361 non-null   object
#  16  Unnamed: 16  2360 non-null   object
#  17  Unnamed: 17  2607 non-null   object
# ...

# %%
ventas_2022
# Out:
#                                              Unnamed: 0              Total  \
# 0                                                   NaN         enero 2022
# 1                                                   NaN  Cantidad producto
# 2                                                 Total          31448.363
# 3                 [000009] Aceite coco Maya gold 450 ml                  4
# 4          [000013] Aceite de girasol Virgen bio Fra...                NaN
# ...                                                 ...                ...
# 3932       [006511] Láminas lasagña de sémola Castag...                NaN
# 3933       [006515] Yogur de avena natural Alpro 500 gr                NaN
# 3934        [006516] Yogur de coco natural Alpro 350 gr                NaN
# 3935       [006518] Yogur vegetal con arandanos Alpr...                NaN
# 3936                [6499] Pularda Sanchonar aprox 3 kg                NaN
#
# ...

# %% [markdown]
# # Analizando Ventas_2021 y 2022

# %%
# Datasets de venta de productos al publico 2021-2022
# ventas_2021= pd.read_excel("Ventas_PVP_inflación_2021.xls")
# ventas_2022= pd.read_excel("Ventas_PVP_inflación_2022.xls")

# %% [markdown]
# ## Ventas_2021

# %%
# Renombrar columnas
ventas_2021.rename(columns={'Unnamed: 0':'Id_Prod', 
                            'Total':'Cant_Prod_Ene',
                            'Unnamed: 2':'Precio_Prod_Ene', 
                            'Unnamed: 3':'Cant_Prod_Feb',
                            'Unnamed: 4':'Precio_Prod_Feb', 
                            'Unnamed: 5':'Cant_Prod_Mar',
                            'Unnamed: 6':'Precio_Prod_Mar', 
                            'Unnamed: 7':'Cant_Prod_Abr',
                            'Unnamed: 8':'Precio_Prod_Abr', 
                            'Unnamed: 9':'Cant_Prod_May',
                            'Unnamed: 10':'Precio_Prod_May', 
                            'Unnamed: 11':'Cant_Prod_Jun',
                            'Unnamed: 12':'Precio_Prod_Jun', 
                            'Unnamed: 13':'Cant_Prod_Jul',
                            'Unnamed: 14':'Precio_Prod_Jul', 
                            'Unnamed: 15':'Cant_Prod_Ago',
                            'Unnamed: 16':'Precio_Prod_Ago', 
                            'Unnamed: 17':'Cant_Prod_Set',
                            'Unnamed: 18':'Precio_Prod_Set', 
                            'Unnamed: 19':'Cant_Prod_Oct', 
                            'Unnamed: 20':'Precio_Prod_Oct', 
                            'Unnamed: 21':'Cant_Prod_Nov', 
                            'Unnamed: 22':'Precio_Prod_Nov', 
                            'Unnamed: 23':'Cant_Prod_Dic', 
                            'Unnamed: 24':'Precio_Prod_Dic', 
                            'Unnamed: 25':'Cant_Total_Prod', 
                            'Unnamed: 26':'Precio_Total_Prod'
                             }, inplace=True)

# %%
# Eliminar 3 filas
ventas_2021_new = ventas_2021.drop([0, 1,2])
ventas_2021_new
# Out:
#                                                 Id_Prod Cant_Prod_Ene  \
# 3          [000007] Aceite árnica y romero Piel sana...           NaN
# 4          [000008] Aceite caléndula y almendras Pie...             2
# 5                 [000009] Aceite coco Maya gold 450 ml           NaN
# 6          [000010] Aceite desmaquillador Piel sana ...           NaN
# 7          [000011] Aceite espliego y rosas Piel san...             4
# ...                                                 ...           ...
# 3874       [006160] Yogur de soja con limón Sojade 4...             4
# 3875       [006161] Yogur de soja con plátano y mara...             5
# 3876        [006162] Yogur de soja natural Sojade 400 g            12
# 3877       [006163] Yogur de soja natural Sojade 4 x...            13
# 3878       [006164] Yogur de soja quark griego Sojad...             6
#
#      Precio_Prod_Ene Cant_Prod_Feb Precio_Prod_Feb Cant_Prod_Mar  \
# ...

# %%
registro = ventas_2021_new.Id_Prod.loc[3875]
print(registro)
# Out:
#      [006161] Yogur de soja con plátano y maracuyá sin azúcar Sojade 400 g

# %%
# Para separar en dos columnas Id_Prod y a la vez eliminar espacios vacios e irregulares
ventas_2021_new["Id_Prod"]=ventas_2021_new["Id_Prod"].astype("category")
ventas_2021_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3876 entries, 3 to 3878
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id_Prod            3876 non-null   category
#  1   Cant_Prod_Ene      1904 non-null   object
#  2   Precio_Prod_Ene    1904 non-null   object
#  3   Cant_Prod_Feb      2064 non-null   object
#  4   Precio_Prod_Feb    2064 non-null   object
#  5   Cant_Prod_Mar      2248 non-null   object
#  6   Precio_Prod_Mar    2248 non-null   object
#  7   Cant_Prod_Abr      2324 non-null   object
#  8   Precio_Prod_Abr    2324 non-null   object
#  9   Cant_Prod_May      2378 non-null   object
#  10  Precio_Prod_May    2378 non-null   object
#  11  Cant_Prod_Jun      2482 non-null   object
#  12  Precio_Prod_Jun    2482 non-null   object
#  13  Cant_Prod_Jul      2462 non-null   object
#  14  Precio_Prod_Jul    2462 non-null   object
#  15  Cant_Prod_Ago      2261 non-null   object
# ...

# %%
# Usamos la expresión regular para extraer el código y el nombre
patron = r'\[(.*?)\]\s*(.*)'
ventas_2021_new[['Id_Prod_2', 'Nom_Prod']] = ventas_2021_new['Id_Prod'].str.extract(patron)

# %%
ventas_2021_new.head(2)
# Out:
#                                              Id_Prod Cant_Prod_Ene  \
# 3       [000007] Aceite árnica y romero Piel sana...           NaN
# 4       [000008] Aceite caléndula y almendras Pie...             2
#
#   Precio_Prod_Ene Cant_Prod_Feb Precio_Prod_Feb Cant_Prod_Mar Precio_Prod_Mar  \
# 3             NaN             1            11.7           NaN             NaN
# 4            12.5           NaN             NaN             1            12.5
#
#   Cant_Prod_Abr Precio_Prod_Abr Cant_Prod_May  ... Cant_Prod_Oct  \
# 3           NaN             NaN           NaN  ...           NaN
# 4           NaN             NaN           NaN  ...           NaN
#
#   Precio_Prod_Oct Cant_Prod_Nov Precio_Prod_Nov Cant_Prod_Dic Precio_Prod_Dic  \
# 3             NaN           NaN             NaN           NaN             NaN
# 4             NaN           NaN             NaN           NaN             NaN
#
#   Cant_Total_Prod Precio_Total_Prod Id_Prod_2  \
# ...

# %%
# Obtén una lista con los nombres de las columnas 
nuevas_columnas = ['Id_Prod_2', 'Nom_Prod'] + list(ventas_2021_new.columns[:-2])

# %%
# Reorganiza el DataFrame 
ventas_2021_new = ventas_2021_new.reindex(columns=nuevas_columnas)
ventas_2021_new.head(3)
# Out:
#   Id_Prod_2                                       Nom_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml
# 5    000009                   Aceite coco Maya gold 450 ml
#
#                                              Id_Prod Cant_Prod_Ene  \
# 3       [000007] Aceite árnica y romero Piel sana...           NaN
# 4       [000008] Aceite caléndula y almendras Pie...             2
# 5              [000009] Aceite coco Maya gold 450 ml           NaN
#
#   Precio_Prod_Ene Cant_Prod_Feb Precio_Prod_Feb Cant_Prod_Mar Precio_Prod_Mar  \
# 3             NaN             1            11.7           NaN             NaN
# 4            12.5           NaN             NaN             1            12.5
# 5             NaN           NaN             NaN           NaN             NaN
#
#   Cant_Prod_Abr  ... Cant_Prod_Set Precio_Prod_Set Cant_Prod_Oct  \
# 3           NaN  ...           NaN             NaN           NaN
# ...

# %%
len(ventas_2021_new)
# Out:
# 3876

# %%
# Eliminar columna Id_Prod
ventas_2021_new=ventas_2021_new.drop("Id_Prod",axis=1)

# %%
ventas_2021_new.head(2)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Ene  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml             2
#
#   Precio_Prod_Ene Cant_Prod_Feb Precio_Prod_Feb Cant_Prod_Mar Precio_Prod_Mar  \
# 3             NaN             1            11.7           NaN             NaN
# 4            12.5           NaN             NaN             1            12.5
#
#   Cant_Prod_Abr Precio_Prod_Abr  ... Cant_Prod_Set Precio_Prod_Set  \
# 3           NaN             NaN  ...           NaN             NaN
# 4           NaN             NaN  ...           NaN             NaN
#
#   Cant_Prod_Oct Precio_Prod_Oct Cant_Prod_Nov Precio_Prod_Nov Cant_Prod_Dic  \
# 3           NaN             NaN           NaN             NaN           NaN
# 4           NaN             NaN           NaN             NaN           NaN
#
#   Precio_Prod_Dic Cant_Total_Prod Precio_Total_Prod
# ...

# %%
# Reasignar nombre del dataframe
dfventas_2021=ventas_2021_new

# %%
# Proceso de transicion, aplicando nueva opcion para desdoblar columnas, verificar resultados por precaución.

# %%
# Separar columnas de Enero
dfventas_Ene_2021 = dfventas_2021.drop(["Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Ene_2021
# Out:
#      Id_Prod_2                                           Nom_Prod  \
# 3       000007            Aceite árnica y romero Piel sana 100 ml
# 4       000008      Aceite caléndula y almendras Piel sana 100 ml
# 5       000009                       Aceite coco Maya gold 450 ml
# 6       000010             Aceite desmaquillador Piel sana 100 ml
# 7       000011           Aceite espliego y rosas Piel sana 100 ml
# ...        ...                                                ...
# 3874    006160               Yogur de soja con limón Sojade 400 g
# 3875    006161  Yogur de soja con plátano y maracuyá sin azúca...
# 3876    006162                 Yogur de soja natural Sojade 400 g
# 3877    006163             Yogur de soja natural Sojade 4 x 100 g
# 3878    006164            Yogur de soja quark griego Sojade 400 g
#
#      Cant_Prod_Ene Precio_Prod_Ene
# 3              NaN             NaN
# 4                2            12.5
# 5              NaN             NaN
# ...

# %%
# En los ultimos registros esta faltando la unidad de medida, verifique con los ultimos registros del primer dataframe.
registro2 = dfventas_Ene_2021.Nom_Prod.loc[3869]
print(registro2)
# Out:
# Yogur de coco con mango Abbot kinney 400 ml

# %%
# crea la lista de fechas especificadas
fecha = "31-01-2021"
lista_fechas_Enero_2021 = [fecha] * len(dfventas_Ene_2021)

# %%
# agrega la nueva columna al DataFrame
dfventas_Ene_2021["fecha"] = lista_fechas_Enero_2021
dfventas_Ene_2021
# Out:
#      Id_Prod_2                                           Nom_Prod  \
# 3       000007            Aceite árnica y romero Piel sana 100 ml
# 4       000008      Aceite caléndula y almendras Piel sana 100 ml
# 5       000009                       Aceite coco Maya gold 450 ml
# 6       000010             Aceite desmaquillador Piel sana 100 ml
# 7       000011           Aceite espliego y rosas Piel sana 100 ml
# ...        ...                                                ...
# 3874    006160               Yogur de soja con limón Sojade 400 g
# 3875    006161  Yogur de soja con plátano y maracuyá sin azúca...
# 3876    006162                 Yogur de soja natural Sojade 400 g
# 3877    006163             Yogur de soja natural Sojade 4 x 100 g
# 3878    006164            Yogur de soja quark griego Sojade 400 g
#
#      Cant_Prod_Ene Precio_Prod_Ene       fecha
# 3              NaN             NaN  31-01-2021
# 4                2            12.5  31-01-2021
# ...

# %%
# Renombrar columnas enero  
dfventas_Ene_2021.rename(columns={'Cant_Prod_Ene':'Cant_Prod', 
                            'Precio_Prod_Ene':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Ene_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml         2
# 5    000009                   Aceite coco Maya gold 450 ml       NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml         4
#
#   Precio_Prod       fecha
# 3         NaN  31-01-2021
# 4        12.5  31-01-2021
# 5         NaN  31-01-2021
# 6         NaN  31-01-2021
# 7        12.5  31-01-2021

# %%
# Separar columnas de Febrero
dfventas_Feb_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Feb_2021
# crea la lista de fechas especificadas
fecha = "28-02-2021"
lista_fechas_febreo_2021 = [fecha] * len(dfventas_Feb_2021)
# agrega la nueva columna al DataFrame
dfventas_Feb_2021["fecha"] = lista_fechas_febreo_2021
dfventas_Feb_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Feb  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml             1
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml           NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml             1
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Feb       fecha
# 3            11.7  28-02-2021
# 4             NaN  28-02-2021
# 5             NaN  28-02-2021
# 6            12.5  28-02-2021
# 7             NaN  28-02-2021

# %%
# Renombrar columnas enero  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Feb_2021.rename(columns={'Cant_Prod_Feb':'Cant_Prod', 
                            'Precio_Prod_Feb':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Feb_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml         1
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml       NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml         1
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3        11.7  28-02-2021
# 4         NaN  28-02-2021
# 5         NaN  28-02-2021
# 6        12.5  28-02-2021
# 7         NaN  28-02-2021

# %%
# Separar columnas de Marzo
dfventas_Mar_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Mar_2021
# crea la lista de fechas especificadas
fecha = "31-03-2021"
lista_fechas_marzo_2021 = [fecha] * len(dfventas_Mar_2021)
# agrega la nueva columna al DataFrame
dfventas_Mar_2021["fecha"] = lista_fechas_marzo_2021
dfventas_Mar_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Mar  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml             1
# 5    000009                   Aceite coco Maya gold 450 ml           NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Mar       fecha
# 3             NaN  31-03-2021
# 4            12.5  31-03-2021
# 5             NaN  31-03-2021
# 6             NaN  31-03-2021
# 7             NaN  31-03-2021

# %%
# Renombrar columnas marzo  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Mar_2021.rename(columns={'Cant_Prod_Mar':'Cant_Prod', 
                            'Precio_Prod_Mar':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Mar_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml         1
# 5    000009                   Aceite coco Maya gold 450 ml       NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  31-03-2021
# 4        12.5  31-03-2021
# 5         NaN  31-03-2021
# 6         NaN  31-03-2021
# 7         NaN  31-03-2021

# %%
# Separar columnas de Abril
dfventas_Abr_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Abr_2021
# crea la lista de fechas especificadas
fecha = "30-04-2021"
lista_fechas_abril_2021 = [fecha] * len(dfventas_Abr_2021)
# agrega la nueva columna al DataFrame
dfventas_Abr_2021["fecha"] = lista_fechas_abril_2021
dfventas_Abr_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Abr  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml           NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Abr       fecha
# 3             NaN  30-04-2021
# 4             NaN  30-04-2021
# 5             NaN  30-04-2021
# 6             NaN  30-04-2021
# 7             NaN  30-04-2021

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Abr_2021.rename(columns={'Cant_Prod_Abr':'Cant_Prod', 
                            'Precio_Prod_Abr':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Abr_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml       NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  30-04-2021
# 4         NaN  30-04-2021
# 5         NaN  30-04-2021
# 6         NaN  30-04-2021
# 7         NaN  30-04-2021

# %%
# Separar columnas de Mayo
dfventas_May_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_May_2021
# crea la lista de fechas especificadas
fecha = "31-05-2021"
lista_fechas_mayo_2021 = [fecha] * len(dfventas_May_2021)
# agrega la nueva columna al DataFrame
dfventas_May_2021["fecha"] = lista_fechas_mayo_2021
dfventas_May_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_May  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml           NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_May       fecha
# 3             NaN  31-05-2021
# 4             NaN  31-05-2021
# 5             NaN  31-05-2021
# 6             NaN  31-05-2021
# 7             NaN  31-05-2021

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_May_2021.rename(columns={'Cant_Prod_May':'Cant_Prod', 
                            'Precio_Prod_May':'Precio_Prod',                            
                             }, inplace=True)
dfventas_May_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml       NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  31-05-2021
# 4         NaN  31-05-2021
# 5         NaN  31-05-2021
# 6         NaN  31-05-2021
# 7         NaN  31-05-2021

# %%
# Separar columnas de Jun
dfventas_Jun_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Jun_2021
# crea la lista de fechas especificadas
fecha = "30-06-2021"
lista_fechas_junio_2021 = [fecha] * len(dfventas_Jun_2021)
# agrega la nueva columna al DataFrame
dfventas_Jun_2021["fecha"] = lista_fechas_junio_2021
dfventas_Jun_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Jun  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml             2
# 5    000009                   Aceite coco Maya gold 450 ml             2
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Jun       fecha
# 3             NaN  30-06-2021
# 4            12.5  30-06-2021
# 5               8  30-06-2021
# 6             NaN  30-06-2021
# 7             NaN  30-06-2021

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Jun_2021.rename(columns={'Cant_Prod_Jun':'Cant_Prod', 
                            'Precio_Prod_Jun':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Jun_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml         2
# 5    000009                   Aceite coco Maya gold 450 ml         2
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  30-06-2021
# 4        12.5  30-06-2021
# 5           8  30-06-2021
# 6         NaN  30-06-2021
# 7         NaN  30-06-2021

# %%
# Separar columnas de Jul
dfventas_Jul_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Jul_2021
# crea la lista de fechas especificadas
fecha = "31-07-2021"
lista_fechas_julio_2021 = [fecha] * len(dfventas_Jul_2021)
# agrega la nueva columna al DataFrame
dfventas_Jul_2021["fecha"] = lista_fechas_julio_2021
dfventas_Jul_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Jul  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml             4
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Jul       fecha
# 3             NaN  31-07-2021
# 4             NaN  31-07-2021
# 5               8  31-07-2021
# 6             NaN  31-07-2021
# 7             NaN  31-07-2021

# %%
# Renombrar columnas 
dfventas_Jul_2021.rename(columns={'Cant_Prod_Jul':'Cant_Prod', 
                            'Precio_Prod_Jul':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Jul_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml         4
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  31-07-2021
# 4         NaN  31-07-2021
# 5           8  31-07-2021
# 6         NaN  31-07-2021
# 7         NaN  31-07-2021

# %%
# Separar columnas de Agosto
dfventas_Ago_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Ago_2021
# crea la lista de fechas especificadas
fecha = "31-08-2021"
lista_fechas_agosto_2021 = [fecha] * len(dfventas_Ago_2021)
# agrega la nueva columna al DataFrame
dfventas_Ago_2021["fecha"] = lista_fechas_agosto_2021
dfventas_Ago_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Ago  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml           NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Ago       fecha
# 3             NaN  31-08-2021
# 4             NaN  31-08-2021
# 5             NaN  31-08-2021
# 6             NaN  31-08-2021
# 7             NaN  31-08-2021

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Ago_2021.rename(columns={'Cant_Prod_Ago':'Cant_Prod', 
                            'Precio_Prod_Ago':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Ago_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml       NaN
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  31-08-2021
# 4         NaN  31-08-2021
# 5         NaN  31-08-2021
# 6         NaN  31-08-2021
# 7         NaN  31-08-2021

# %%
# Separar columnas de Setiembre
dfventas_Set_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Set_2021
# crea la lista de fechas especificadas
fecha = "30-09-2021"
lista_fechas_setiembre_2021 = [fecha] * len(dfventas_Set_2021)
# agrega la nueva columna al DataFrame
dfventas_Set_2021["fecha"] = lista_fechas_setiembre_2021
dfventas_Set_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Set  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml             6
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Set       fecha
# 3             NaN  30-09-2021
# 4             NaN  30-09-2021
# 5               8  30-09-2021
# 6             NaN  30-09-2021
# 7             NaN  30-09-2021

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Set_2021.rename(columns={'Cant_Prod_Set':'Cant_Prod', 
                            'Precio_Prod_Set':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Set_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml         6
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  30-09-2021
# 4         NaN  30-09-2021
# 5           8  30-09-2021
# 6         NaN  30-09-2021
# 7         NaN  30-09-2021

# %%
# Separar columnas de Octubre
dfventas_Oct_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Oct_2021
# crea la lista de fechas especificadas
fecha = "31-10-2021"
lista_fechas_octubre_2021 = [fecha] * len(dfventas_Oct_2021)
# agrega la nueva columna al DataFrame
dfventas_Oct_2021["fecha"] = lista_fechas_octubre_2021
dfventas_Oct_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Oct  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml             2
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Oct       fecha
# 3             NaN  31-10-2021
# 4             NaN  31-10-2021
# 5               8  31-10-2021
# 6             NaN  31-10-2021
# 7             NaN  31-10-2021

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Oct_2021.rename(columns={'Cant_Prod_Oct':'Cant_Prod', 
                            'Precio_Prod_Oct':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Oct_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml         2
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  31-10-2021
# 4         NaN  31-10-2021
# 5           8  31-10-2021
# 6         NaN  31-10-2021
# 7         NaN  31-10-2021

# %%
# Separar columnas de Noviembre
dfventas_Nov_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Nov_2021
# crea la lista de fechas especificadas
fecha = "30-11-2021"
lista_fechas_noviembre_2021 = [fecha] * len(dfventas_Nov_2021)
# agrega la nueva columna al DataFrame
dfventas_Nov_2021["fecha"] = lista_fechas_noviembre_2021
dfventas_Nov_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Nov  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml             2
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Nov       fecha
# 3             NaN  30-11-2021
# 4             NaN  30-11-2021
# 5               8  30-11-2021
# 6             NaN  30-11-2021
# 7             NaN  30-11-2021

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Nov_2021.rename(columns={'Cant_Prod_Nov':'Cant_Prod', 
                            'Precio_Prod_Nov':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Nov_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml         2
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  30-11-2021
# 4         NaN  30-11-2021
# 5           8  30-11-2021
# 6         NaN  30-11-2021
# 7         NaN  30-11-2021

# %%
# Separar columnas de Diciemre
dfventas_Dic_2021 = dfventas_2021.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Dic_2021
# crea la lista de fechas especificadas
fecha = "31-12-2021"
lista_fechas_diciembre_2021 = [fecha] * len(dfventas_Dic_2021)
# agrega la nueva columna al DataFrame
dfventas_Dic_2021["fecha"] = lista_fechas_diciembre_2021
dfventas_Dic_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Dic  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml           NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml           NaN
# 5    000009                   Aceite coco Maya gold 450 ml             2
# 6    000010         Aceite desmaquillador Piel sana 100 ml           NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml           NaN
#
#   Precio_Prod_Dic       fecha
# 3             NaN  31-12-2021
# 4             NaN  31-12-2021
# 5               8  31-12-2021
# 6             NaN  31-12-2021
# 7             NaN  31-12-2021

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Dic_2021.rename(columns={'Cant_Prod_Dic':'Cant_Prod', 
                            'Precio_Prod_Dic':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Dic_2021.head(5)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 3    000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 4    000008  Aceite caléndula y almendras Piel sana 100 ml       NaN
# 5    000009                   Aceite coco Maya gold 450 ml         2
# 6    000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 7    000011       Aceite espliego y rosas Piel sana 100 ml       NaN
#
#   Precio_Prod       fecha
# 3         NaN  31-12-2021
# 4         NaN  31-12-2021
# 5           8  31-12-2021
# 6         NaN  31-12-2021
# 7         NaN  31-12-2021

# %%
len(dfventas_Dic_2021)
# Out:
# 3876

# %%
# Concatenar dataframe
dfventas_2021 = pd.concat([dfventas_Ene_2021, dfventas_Feb_2021, dfventas_Mar_2021, dfventas_Abr_2021, dfventas_May_2021, dfventas_Jun_2021, dfventas_Jul_2021, dfventas_Ago_2021, dfventas_Set_2021, dfventas_Oct_2021, dfventas_Nov_2021, dfventas_Dic_2021], axis=0)
dfventas_2021.reset_index(inplace=True, drop=True)
dfventas_2021
# Out:
#       Id_Prod_2                                           Nom_Prod Cant_Prod  \
# 0        000007            Aceite árnica y romero Piel sana 100 ml       NaN
# 1        000008      Aceite caléndula y almendras Piel sana 100 ml         2
# 2        000009                       Aceite coco Maya gold 450 ml       NaN
# 3        000010             Aceite desmaquillador Piel sana 100 ml       NaN
# 4        000011           Aceite espliego y rosas Piel sana 100 ml         4
# ...         ...                                                ...       ...
# 46507    006160               Yogur de soja con limón Sojade 400 g        16
# 46508    006161  Yogur de soja con plátano y maracuyá sin azúca...         8
# 46509    006162                 Yogur de soja natural Sojade 400 g        12
# 46510    006163             Yogur de soja natural Sojade 4 x 100 g         9
# 46511    006164            Yogur de soja quark griego Sojade 400 g        22
#
#       Precio_Prod       fecha
# ...

# %%
# Convertir la columna de fecha al formato adecuado
dfventas_2021['fecha'] = pd.to_datetime(dfventas_2021['fecha'], format='%d-%m-%Y')

# %%
# probamos eliminado NAN
dfventas_sin_nan = dfventas_2021

# %%
dfventas_sin_nan = dfventas_sin_nan.dropna()
dfventas_sin_nan
# Out:
#       Id_Prod_2                                           Nom_Prod Cant_Prod  \
# 1        000008      Aceite caléndula y almendras Piel sana 100 ml         2
# 4        000011           Aceite espliego y rosas Piel sana 100 ml         4
# 9        000018     Aceite oliva virgen extra Umbria Oretana 2.5 L         9
# 10       000019  Aceite oliva virgen extra Umbria oretana 500 m...         1
# 11       000020       Aceite oliva virgen extra Umbria oretana 5 L         5
# ...         ...                                                ...       ...
# 46507    006160               Yogur de soja con limón Sojade 400 g        16
# 46508    006161  Yogur de soja con plátano y maracuyá sin azúca...         8
# 46509    006162                 Yogur de soja natural Sojade 400 g        12
# 46510    006163             Yogur de soja natural Sojade 4 x 100 g         9
# 46511    006164            Yogur de soja quark griego Sojade 400 g        22
#
#       Precio_Prod      fecha
# ...

# %%
# Probamos reemplazando NaN con cero
dfventas_con_cero = dfventas_2021

# %%
dfventas_con_cero = dfventas_con_cero.fillna(0)
dfventas_con_cero
# Out:
#       Id_Prod_2                                           Nom_Prod  Cant_Prod  \
# 0        000007            Aceite árnica y romero Piel sana 100 ml        0.0
# 1        000008      Aceite caléndula y almendras Piel sana 100 ml        2.0
# 2        000009                       Aceite coco Maya gold 450 ml        0.0
# 3        000010             Aceite desmaquillador Piel sana 100 ml        0.0
# 4        000011           Aceite espliego y rosas Piel sana 100 ml        4.0
# ...         ...                                                ...        ...
# 46507    006160               Yogur de soja con limón Sojade 400 g       16.0
# 46508    006161  Yogur de soja con plátano y maracuyá sin azúca...        8.0
# 46509    006162                 Yogur de soja natural Sojade 400 g       12.0
# 46510    006163             Yogur de soja natural Sojade 4 x 100 g        9.0
# 46511    006164            Yogur de soja quark griego Sojade 400 g       22.0
#
#        Precio_Prod      fecha
# ...

# %% [markdown]
# ### Ventas_2022

# %%
#Datasets de venta de productos al publico 2021
ventas_2022= pd.read_excel("Ventas_PVP_inflación_2022.xls")
ventas_2022
# Out:
#                                              Unnamed: 0              Total  \
# 0                                                   NaN         enero 2022
# 1                                                   NaN  Cantidad producto
# 2                                                 Total          31448.363
# 3                 [000009] Aceite coco Maya gold 450 ml                  4
# 4          [000013] Aceite de girasol Virgen bio Fra...                NaN
# ...                                                 ...                ...
# 3932       [006511] Láminas lasagña de sémola Castag...                NaN
# 3933       [006515] Yogur de avena natural Alpro 500 gr                NaN
# 3934        [006516] Yogur de coco natural Alpro 350 gr                NaN
# 3935       [006518] Yogur vegetal con arandanos Alpr...                NaN
# 3936                [6499] Pularda Sanchonar aprox 3 kg                NaN
#
# ...

# %%
# Visualizar columnas
ventas_2022.columns
# Out:
# Index(['Unnamed: 0', 'Total', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26'],
#       dtype='object')

# %%
# Renombrar columnas
ventas_2022.rename(columns={'Unnamed: 0':'Id_Prod', 
                            'Total':'Cant_Prod_Ene',
                            'Unnamed: 2':'Precio_Prod_Ene', 
                            'Unnamed: 3':'Cant_Prod_Feb',
                            'Unnamed: 4':'Precio_Prod_Feb', 
                            'Unnamed: 5':'Cant_Prod_Mar',
                            'Unnamed: 6':'Precio_Prod_Mar', 
                            'Unnamed: 7':'Cant_Prod_Abr',
                            'Unnamed: 8':'Precio_Prod_Abr', 
                            'Unnamed: 9':'Cant_Prod_May',
                            'Unnamed: 10':'Precio_Prod_May', 
                            'Unnamed: 11':'Cant_Prod_Jun',
                            'Unnamed: 12':'Precio_Prod_Jun', 
                            'Unnamed: 13':'Cant_Prod_Jul',
                            'Unnamed: 14':'Precio_Prod_Jul', 
                            'Unnamed: 15':'Cant_Prod_Ago',
                            'Unnamed: 16':'Precio_Prod_Ago', 
                            'Unnamed: 17':'Cant_Prod_Set',
                            'Unnamed: 18':'Precio_Prod_Set', 
                            'Unnamed: 19':'Cant_Prod_Oct', 
                            'Unnamed: 20':'Precio_Prod_Oct', 
                            'Unnamed: 21':'Cant_Prod_Nov', 
                            'Unnamed: 22':'Precio_Prod_Nov', 
                            'Unnamed: 23':'Cant_Prod_Dic', 
                            'Unnamed: 24':'Precio_Prod_Dic', 
                            'Unnamed: 25':'Cant_Total_Prod', 
                            'Unnamed: 26':'Precio_Total_Prod'
                             }, inplace=True)

# %%
ventas_2022
# Out:
#                                                 Id_Prod      Cant_Prod_Ene  \
# 0                                                   NaN         enero 2022
# 1                                                   NaN  Cantidad producto
# 2                                                 Total          31448.363
# 3                 [000009] Aceite coco Maya gold 450 ml                  4
# 4          [000013] Aceite de girasol Virgen bio Fra...                NaN
# ...                                                 ...                ...
# 3932       [006511] Láminas lasagña de sémola Castag...                NaN
# 3933       [006515] Yogur de avena natural Alpro 500 gr                NaN
# 3934        [006516] Yogur de coco natural Alpro 350 gr                NaN
# 3935       [006518] Yogur vegetal con arandanos Alpr...                NaN
# 3936                [6499] Pularda Sanchonar aprox 3 kg                NaN
#
# ...

# %%
# Eliminar 3 filas
ventas_2022_new = ventas_2022.drop([0, 1,2])
ventas_2022_new
# Out:
#                                                 Id_Prod Cant_Prod_Ene  \
# 3                 [000009] Aceite coco Maya gold 450 ml             4
# 4          [000013] Aceite de girasol Virgen bio Fra...           NaN
# 5          [000018] Aceite oliva virgen extra Umbria...             1
# 6          [000020] Aceite oliva virgen extra Umbria...             1
# 7          [000021] Aceite oliva virgen extra Umbria...             2
# ...                                                 ...           ...
# 3932       [006511] Láminas lasagña de sémola Castag...           NaN
# 3933       [006515] Yogur de avena natural Alpro 500 gr           NaN
# 3934        [006516] Yogur de coco natural Alpro 350 gr           NaN
# 3935       [006518] Yogur vegetal con arandanos Alpr...           NaN
# 3936                [6499] Pularda Sanchonar aprox 3 kg           NaN
#
#      Precio_Prod_Ene Cant_Prod_Feb Precio_Prod_Feb Cant_Prod_Mar  \
# ...

# %%
registro = ventas_2022_new.Id_Prod.loc[3875]
print(registro)
# Out:
#      [006425] Hummus De Cúrcuma Fresco Bio Vegetalia 220g.

# %%
registro = ventas_2022_new.Id_Prod.loc[3935]
print(registro)
# Out:
#      [006518] Yogur vegetal con arandanos Alpro 500 gr

# %%
registro = ventas_2022_new.Id_Prod.loc[3936]
print(registro)
# Out:
#      [6499] Pularda Sanchonar aprox 3 kg

# %%
# Proceso para separar dos columnas a partir de Id_Prod
ventas_2022_new["Id_Prod"]=ventas_2022_new["Id_Prod"].astype("category")
ventas_2022_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3934 entries, 3 to 3936
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id_Prod            3934 non-null   category
#  1   Cant_Prod_Ene      2720 non-null   object
#  2   Precio_Prod_Ene    2720 non-null   object
#  3   Cant_Prod_Feb      2659 non-null   object
#  4   Precio_Prod_Feb    2659 non-null   object
#  5   Cant_Prod_Mar      2747 non-null   object
#  6   Precio_Prod_Mar    2747 non-null   object
#  7   Cant_Prod_Abr      2738 non-null   object
#  8   Precio_Prod_Abr    2738 non-null   object
#  9   Cant_Prod_May      2665 non-null   object
#  10  Precio_Prod_May    2665 non-null   object
#  11  Cant_Prod_Jun      2602 non-null   object
#  12  Precio_Prod_Jun    2602 non-null   object
#  13  Cant_Prod_Jul      2523 non-null   object
#  14  Precio_Prod_Jul    2523 non-null   object
#  15  Cant_Prod_Ago      2358 non-null   object
# ...

# %%
# Usamos la expresión regular para extraer el código y el nombre
patron = r'\[(.*?)\]\s*(.*)'
ventas_2022_new[['Id_Prod_2', 'Nom_Prod']] = ventas_2022_new['Id_Prod'].str.extract(patron)

# %%
ventas_2022_new.head(2)
# Out:
#                                              Id_Prod Cant_Prod_Ene  \
# 3              [000009] Aceite coco Maya gold 450 ml             4
# 4       [000013] Aceite de girasol Virgen bio Fra...           NaN
#
#   Precio_Prod_Ene Cant_Prod_Feb Precio_Prod_Feb Cant_Prod_Mar Precio_Prod_Mar  \
# 3               8             2               8             2               8
# 4             NaN             2            4.15             3            4.15
#
#   Cant_Prod_Abr Precio_Prod_Abr Cant_Prod_May  ... Cant_Prod_Oct  \
# 3             1               8             4  ...             2
# 4             1            4.15           NaN  ...           NaN
#
#   Precio_Prod_Oct Cant_Prod_Nov Precio_Prod_Nov Cant_Prod_Dic Precio_Prod_Dic  \
# 3               8             2               8             1               8
# 4             NaN           NaN             NaN           NaN             NaN
#
#   Cant_Total_Prod Precio_Total_Prod Id_Prod_2  \
# ...

# %%
# Obtén una lista con los nombres de las columnas 
nuevas_columnas = ['Id_Prod_2', 'Nom_Prod'] + list(ventas_2022_new.columns[:-2])

# Reorganiza el DataFrame 
ventas_2022_new = ventas_2022_new.reindex(columns=nuevas_columnas)
ventas_2022_new.head(3)
# Out:
#   Id_Prod_2                                        Nom_Prod  \
# 3    000009                    Aceite coco Maya gold 450 ml
# 4    000013   Aceite de girasol Virgen bio Franciscanos 1 L
# 5    000018  Aceite oliva virgen extra Umbria Oretana 2.5 L
#
#                                              Id_Prod Cant_Prod_Ene  \
# 3              [000009] Aceite coco Maya gold 450 ml             4
# 4       [000013] Aceite de girasol Virgen bio Fra...           NaN
# 5       [000018] Aceite oliva virgen extra Umbria...             1
#
#   Precio_Prod_Ene Cant_Prod_Feb Precio_Prod_Feb Cant_Prod_Mar Precio_Prod_Mar  \
# 3               8             2               8             2               8
# 4             NaN             2            4.15             3            4.15
# 5            18.5             7            18.5             7            18.5
#
#   Cant_Prod_Abr  ... Cant_Prod_Set Precio_Prod_Set Cant_Prod_Oct  \
# 3             1  ...           NaN             NaN             2
# ...

# %%
# Eliminar columna Id_Prod
ventas_2022_new=ventas_2022_new.drop("Id_Prod",axis=1)

# %%
ventas_2022_new.head(2)
# Out:
#   Id_Prod_2                                       Nom_Prod Cant_Prod_Ene  \
# 3    000009                   Aceite coco Maya gold 450 ml             4
# 4    000013  Aceite de girasol Virgen bio Franciscanos 1 L           NaN
#
#   Precio_Prod_Ene Cant_Prod_Feb Precio_Prod_Feb Cant_Prod_Mar Precio_Prod_Mar  \
# 3               8             2               8             2               8
# 4             NaN             2            4.15             3            4.15
#
#   Cant_Prod_Abr Precio_Prod_Abr  ... Cant_Prod_Set Precio_Prod_Set  \
# 3             1               8  ...           NaN             NaN
# 4             1            4.15  ...           NaN             NaN
#
#   Cant_Prod_Oct Precio_Prod_Oct Cant_Prod_Nov Precio_Prod_Nov Cant_Prod_Dic  \
# 3             2               8             2               8             1
# 4           NaN             NaN           NaN             NaN           NaN
#
#   Precio_Prod_Dic Cant_Total_Prod Precio_Total_Prod
# ...

# %%
# Reasignar nombre del dataframe
dfventas_2022=ventas_2022_new

# %%
# Separar columnas de Enero
dfventas_Ene_2022 = dfventas_2022.drop(["Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Ene_2022
# Out:
#      Id_Prod_2                                          Nom_Prod  \
# 3       000009                      Aceite coco Maya gold 450 ml
# 4       000013     Aceite de girasol Virgen bio Franciscanos 1 L
# 5       000018    Aceite oliva virgen extra Umbria Oretana 2.5 L
# 6       000020      Aceite oliva virgen extra Umbria oretana 5 L
# 7       000021  Aceite oliva virgen extra Umbria oretana 5 L PET
# ...        ...                                               ...
# 3932    006511          Láminas lasagña de sémola Castagno 500 g
# 3933    006515               Yogur de avena natural Alpro 500 gr
# 3934    006516                Yogur de coco natural Alpro 350 gr
# 3935    006518          Yogur vegetal con arandanos Alpro 500 gr
# 3936      6499                      Pularda Sanchonar aprox 3 kg
#
#      Cant_Prod_Ene Precio_Prod_Ene
# 3                4               8
# 4              NaN             NaN
# 5                1            18.5
# 6                1           32.75
# ...

# %%
# En los ultimos registros esta faltando la unidad de medida, verifique con los ultimos registros del primer dataframe.
registro2 = dfventas_Ene_2022.Nom_Prod.loc[3869]
print(registro2)
# Out:
# Pate De Finas Hierbas Pequeño Bio Vegetalia 110g.

# %%
# crea la lista de fechas especificadas
fecha = "31-01-2022"
lista_fechas_Enero_2022 = [fecha] * len(dfventas_Ene_2022)

# %%
# agrega la nueva columna al DataFrame
dfventas_Ene_2022["fecha"] = lista_fechas_Enero_2022
dfventas_Ene_2022
# Out:
#      Id_Prod_2                                          Nom_Prod  \
# 3       000009                      Aceite coco Maya gold 450 ml
# 4       000013     Aceite de girasol Virgen bio Franciscanos 1 L
# 5       000018    Aceite oliva virgen extra Umbria Oretana 2.5 L
# 6       000020      Aceite oliva virgen extra Umbria oretana 5 L
# 7       000021  Aceite oliva virgen extra Umbria oretana 5 L PET
# ...        ...                                               ...
# 3932    006511          Láminas lasagña de sémola Castagno 500 g
# 3933    006515               Yogur de avena natural Alpro 500 gr
# 3934    006516                Yogur de coco natural Alpro 350 gr
# 3935    006518          Yogur vegetal con arandanos Alpro 500 gr
# 3936      6499                      Pularda Sanchonar aprox 3 kg
#
#      Cant_Prod_Ene Precio_Prod_Ene       fecha
# 3                4               8  31-01-2022
# 4              NaN             NaN  31-01-2022
# ...

# %%
# Renombrar columnas enero  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Ene_2022.rename(columns={'Cant_Prod_Ene':'Cant_Prod', 
                            'Precio_Prod_Ene':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Ene_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         4
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         1
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         1
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         2
#
#   Precio_Prod       fecha
# 3           8  31-01-2022
# 4         NaN  31-01-2022
# 5        18.5  31-01-2022
# 6       32.75  31-01-2022
# 7        30.5  31-01-2022

# %%
# Separar columnas de Febrero
dfventas_Feb_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Feb_2022
# crea la lista de fechas especificadas
fecha = "28-02-2022"
lista_fechas_febreo_2022 = [fecha] * len(dfventas_Feb_2022)
# agrega la nueva columna al DataFrame
dfventas_Feb_2022["fecha"] = lista_fechas_febreo_2022
dfventas_Feb_2022.head(3)
# Out:
#   Id_Prod_2                                        Nom_Prod Cant_Prod_Feb  \
# 3    000009                    Aceite coco Maya gold 450 ml             2
# 4    000013   Aceite de girasol Virgen bio Franciscanos 1 L             2
# 5    000018  Aceite oliva virgen extra Umbria Oretana 2.5 L             7
#
#   Precio_Prod_Feb       fecha
# 3               8  28-02-2022
# 4            4.15  28-02-2022
# 5            18.5  28-02-2022

# %%
# Renombrar columnas enero  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Feb_2022.rename(columns={'Cant_Prod_Feb':'Cant_Prod', 
                            'Precio_Prod_Feb':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Feb_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L         2
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         7
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         7
#
#   Precio_Prod       fecha
# 3           8  28-02-2022
# 4        4.15  28-02-2022
# 5        18.5  28-02-2022
# 6       32.75  28-02-2022
# 7        30.5  28-02-2022

# %%
# Separar columnas de Marzo
dfventas_Mar_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Mar_2022
# crea la lista de fechas especificadas
fecha = "31-03-2022"
lista_fechas_marzo_2022 = [fecha] * len(dfventas_Mar_2022)
# agrega la nueva columna al DataFrame
dfventas_Mar_2022["fecha"] = lista_fechas_marzo_2022
dfventas_Mar_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Mar  \
# 3    000009                      Aceite coco Maya gold 450 ml             2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L             3
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             8
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET            14
#
#   Precio_Prod_Mar       fecha
# 3               8  31-03-2022
# 4            4.15  31-03-2022
# 5            18.5  31-03-2022
# 6           32.75  31-03-2022
# 7            30.5  31-03-2022

# %%
# Renombrar columnas marzo  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Mar_2022.rename(columns={'Cant_Prod_Mar':'Cant_Prod', 
                            'Precio_Prod_Mar':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Mar_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L         3
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         8
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET        14
#
#   Precio_Prod       fecha
# 3           8  31-03-2022
# 4        4.15  31-03-2022
# 5        18.5  31-03-2022
# 6       32.75  31-03-2022
# 7        30.5  31-03-2022

# %%
# Separar columnas de Abril
dfventas_Abr_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Abr_2022
# crea la lista de fechas especificadas
fecha = "30-04-2022"
lista_fechas_abril_2022 = [fecha] * len(dfventas_Abr_2022)
# agrega la nueva columna al DataFrame
dfventas_Abr_2022["fecha"] = lista_fechas_abril_2022
dfventas_Abr_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Abr  \
# 3    000009                      Aceite coco Maya gold 450 ml             1
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L             1
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             9
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             5
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET             6
#
#   Precio_Prod_Abr       fecha
# 3               8  30-04-2022
# 4            4.15  30-04-2022
# 5            18.5  30-04-2022
# 6           32.75  30-04-2022
# 7            30.5  30-04-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Abr_2022.rename(columns={'Cant_Prod_Abr':'Cant_Prod', 
                            'Precio_Prod_Abr':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Abr_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         1
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L         1
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         9
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         5
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         6
#
#   Precio_Prod       fecha
# 3           8  30-04-2022
# 4        4.15  30-04-2022
# 5        18.5  30-04-2022
# 6       32.75  30-04-2022
# 7        30.5  30-04-2022

# %%
# Separar columnas de Mayo
dfventas_May_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_May_2022
# crea la lista de fechas especificadas
fecha = "31-05-2022"
lista_fechas_mayo_2022 = [fecha] * len(dfventas_May_2022)
# agrega la nueva columna al DataFrame
dfventas_May_2022["fecha"] = lista_fechas_mayo_2022
dfventas_May_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_May  \
# 3    000009                      Aceite coco Maya gold 450 ml             4
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L           NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             5
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             2
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET             2
#
#   Precio_Prod_May       fecha
# 3               8  31-05-2022
# 4             NaN  31-05-2022
# 5            18.5  31-05-2022
# 6           32.75  31-05-2022
# 7            30.5  31-05-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_May_2022.rename(columns={'Cant_Prod_May':'Cant_Prod', 
                            'Precio_Prod_May':'Precio_Prod',                            
                             }, inplace=True)
dfventas_May_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         4
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         5
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         2
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         2
#
#   Precio_Prod       fecha
# 3           8  31-05-2022
# 4         NaN  31-05-2022
# 5        18.5  31-05-2022
# 6       32.75  31-05-2022
# 7        30.5  31-05-2022

# %%
# Separar columnas de Jun
dfventas_Jun_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Jun_2022
# crea la lista de fechas especificadas
fecha = "30-06-2022"
lista_fechas_junio_2022 = [fecha] * len(dfventas_Jun_2022)
# agrega la nueva columna al DataFrame
dfventas_Jun_2022["fecha"] = lista_fechas_junio_2022
dfventas_Jun_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Jun  \
# 3    000009                      Aceite coco Maya gold 450 ml             2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L           NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             2
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             3
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET             3
#
#   Precio_Prod_Jun       fecha
# 3               8  30-06-2022
# 4             NaN  30-06-2022
# 5            18.5  30-06-2022
# 6           32.75  30-06-2022
# 7            30.5  30-06-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Jun_2022.rename(columns={'Cant_Prod_Jun':'Cant_Prod', 
                            'Precio_Prod_Jun':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Jun_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         2
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         3
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         3
#
#   Precio_Prod       fecha
# 3           8  30-06-2022
# 4         NaN  30-06-2022
# 5        18.5  30-06-2022
# 6       32.75  30-06-2022
# 7        30.5  30-06-2022

# %%
# Separar columnas de Jul
dfventas_Jul_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Jul_2022
# crea la lista de fechas especificadas
fecha = "31-07-2022"
lista_fechas_julio_2022 = [fecha] * len(dfventas_Jul_2022)
# agrega la nueva columna al DataFrame
dfventas_Jul_2022["fecha"] = lista_fechas_julio_2022
dfventas_Jul_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Jul  \
# 3    000009                      Aceite coco Maya gold 450 ml             1
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L           NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             2
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             6
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET             5
#
#   Precio_Prod_Jul       fecha
# 3               8  31-07-2022
# 4             NaN  31-07-2022
# 5            18.5  31-07-2022
# 6           32.75  31-07-2022
# 7            30.5  31-07-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Jul_2022.rename(columns={'Cant_Prod_Jul':'Cant_Prod', 
                            'Precio_Prod_Jul':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Jul_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         1
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         2
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         6
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         5
#
#   Precio_Prod       fecha
# 3           8  31-07-2022
# 4         NaN  31-07-2022
# 5        18.5  31-07-2022
# 6       32.75  31-07-2022
# 7        30.5  31-07-2022

# %%
# Separar columnas de Agosto
dfventas_Ago_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Ago_2022
# crea la lista de fechas especificadas
fecha = "31-08-2022"
lista_fechas_agosto_2022 = [fecha] * len(dfventas_Ago_2022)
# agrega la nueva columna al DataFrame
dfventas_Ago_2022["fecha"] = lista_fechas_agosto_2022
dfventas_Ago_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Ago  \
# 3    000009                      Aceite coco Maya gold 450 ml           NaN
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L           NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             4
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             4
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET             5
#
#   Precio_Prod_Ago       fecha
# 3             NaN  31-08-2022
# 4             NaN  31-08-2022
# 5            18.5  31-08-2022
# 6           32.75  31-08-2022
# 7            30.5  31-08-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Ago_2022.rename(columns={'Cant_Prod_Ago':'Cant_Prod', 
                            'Precio_Prod_Ago':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Ago_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml       NaN
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         4
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         4
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         5
#
#   Precio_Prod       fecha
# 3         NaN  31-08-2022
# 4         NaN  31-08-2022
# 5        18.5  31-08-2022
# 6       32.75  31-08-2022
# 7        30.5  31-08-2022

# %%
# Separar columnas de Setiembre
dfventas_Set_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Set_2022
# crea la lista de fechas especificadas
fecha = "30-09-2022"
lista_fechas_setiembre_2022 = [fecha] * len(dfventas_Set_2022)
# agrega la nueva columna al DataFrame
dfventas_Set_2022["fecha"] = lista_fechas_setiembre_2022
dfventas_Set_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Set  \
# 3    000009                      Aceite coco Maya gold 450 ml           NaN
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L           NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             7
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET             7
#
#   Precio_Prod_Set       fecha
# 3             NaN  30-09-2022
# 4             NaN  30-09-2022
# 5            18.5  30-09-2022
# 6           32.75  30-09-2022
# 7            30.5  30-09-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Set_2022.rename(columns={'Cant_Prod_Set':'Cant_Prod', 
                            'Precio_Prod_Set':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Set_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml       NaN
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         7
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         7
#
#   Precio_Prod       fecha
# 3         NaN  30-09-2022
# 4         NaN  30-09-2022
# 5        18.5  30-09-2022
# 6       32.75  30-09-2022
# 7        30.5  30-09-2022

# %%
# Separar columnas de Octubre
dfventas_Oct_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Oct_2022
# crea la lista de fechas especificadas
fecha = "31-10-2022"
lista_fechas_octubre_2022 = [fecha] * len(dfventas_Oct_2022)
# agrega la nueva columna al DataFrame
dfventas_Oct_2022["fecha"] = lista_fechas_octubre_2022
dfventas_Oct_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Oct  \
# 3    000009                      Aceite coco Maya gold 450 ml             2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L           NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             6
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             4
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET             5
#
#   Precio_Prod_Oct       fecha
# 3               8  31-10-2022
# 4             NaN  31-10-2022
# 5            18.5  31-10-2022
# 6           32.75  31-10-2022
# 7            30.5  31-10-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Oct_2022.rename(columns={'Cant_Prod_Oct':'Cant_Prod', 
                            'Precio_Prod_Oct':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Oct_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         6
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         4
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         5
#
#   Precio_Prod       fecha
# 3           8  31-10-2022
# 4         NaN  31-10-2022
# 5        18.5  31-10-2022
# 6       32.75  31-10-2022
# 7        30.5  31-10-2022

# %%
# Separar columnas de Noviembre
dfventas_Nov_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Dic","Precio_Prod_Dic","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Nov_2022
# crea la lista de fechas especificadas
fecha = "30-11-2022"
lista_fechas_noviembre_2022 = [fecha] * len(dfventas_Nov_2022)
# agrega la nueva columna al DataFrame
dfventas_Nov_2022["fecha"] = lista_fechas_noviembre_2022
dfventas_Nov_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Nov  \
# 3    000009                      Aceite coco Maya gold 450 ml             2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L           NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L             4
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET             4
#
#   Precio_Prod_Nov       fecha
# 3               8  30-11-2022
# 4             NaN  30-11-2022
# 5            18.5  30-11-2022
# 6           32.75  30-11-2022
# 7            30.5  30-11-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Nov_2022.rename(columns={'Cant_Prod_Nov':'Cant_Prod', 
                            'Precio_Prod_Nov':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Nov_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         2
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L         4
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET         4
#
#   Precio_Prod       fecha
# 3           8  30-11-2022
# 4         NaN  30-11-2022
# 5        18.5  30-11-2022
# 6       32.75  30-11-2022
# 7        30.5  30-11-2022

# %%
# Separar columnas de Diciemre
dfventas_Dic_2022 = dfventas_2022.drop(["Cant_Prod_Ene","Precio_Prod_Ene","Cant_Prod_Feb","Precio_Prod_Feb","Cant_Prod_Mar","Precio_Prod_Mar","Cant_Prod_Abr","Precio_Prod_Abr","Cant_Prod_May","Precio_Prod_May","Cant_Prod_Jun","Precio_Prod_Jun","Cant_Prod_Jul","Precio_Prod_Jul","Cant_Prod_Ago","Precio_Prod_Ago","Cant_Prod_Set","Precio_Prod_Set","Cant_Prod_Oct","Precio_Prod_Oct","Cant_Prod_Nov","Precio_Prod_Nov","Cant_Total_Prod","Precio_Total_Prod"], axis=1)
dfventas_Dic_2022
# crea la lista de fechas especificadas
fecha = "31-12-2022"
lista_fechas_diciembre_2022 = [fecha] * len(dfventas_Dic_2022)
# agrega la nueva columna al DataFrame
dfventas_Dic_2022["fecha"] = lista_fechas_diciembre_2022
dfventas_Dic_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod_Dic  \
# 3    000009                      Aceite coco Maya gold 450 ml             1
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L           NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L             7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L           NaN
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET           NaN
#
#   Precio_Prod_Dic       fecha
# 3               8  31-12-2022
# 4             NaN  31-12-2022
# 5            18.5  31-12-2022
# 6             NaN  31-12-2022
# 7             NaN  31-12-2022

# %%
# Renombrar columnas ___  OJO SI NO FUNCIONA ELIMINAR ESTA COLUMNA
dfventas_Dic_2022.rename(columns={'Cant_Prod_Dic':'Cant_Prod', 
                            'Precio_Prod_Dic':'Precio_Prod',                            
                             }, inplace=True)
dfventas_Dic_2022.head(5)
# Out:
#   Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 3    000009                      Aceite coco Maya gold 450 ml         1
# 4    000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 5    000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         7
# 6    000020      Aceite oliva virgen extra Umbria oretana 5 L       NaN
# 7    000021  Aceite oliva virgen extra Umbria oretana 5 L PET       NaN
#
#   Precio_Prod       fecha
# 3           8  31-12-2022
# 4         NaN  31-12-2022
# 5        18.5  31-12-2022
# 6         NaN  31-12-2022
# 7         NaN  31-12-2022

# %%
len(dfventas_Dic_2022)
# Out:
# 3934

# %%
# Concatenar dataframe
dfventas_2022 = pd.concat([dfventas_Ene_2022, dfventas_Feb_2022, dfventas_Mar_2022, dfventas_Abr_2022, dfventas_May_2022, dfventas_Jun_2022, dfventas_Jul_2022, dfventas_Ago_2022, dfventas_Set_2022, dfventas_Oct_2022, dfventas_Nov_2022, dfventas_Dic_2022], axis=0)
dfventas_2022.reset_index(inplace=True, drop=True)
dfventas_2022
# Out:
#       Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 0        000009                      Aceite coco Maya gold 450 ml         4
# 1        000013     Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 2        000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         1
# 3        000020      Aceite oliva virgen extra Umbria oretana 5 L         1
# 4        000021  Aceite oliva virgen extra Umbria oretana 5 L PET         2
# ...         ...                                               ...       ...
# 47203    006511          Láminas lasagña de sémola Castagno 500 g         2
# 47204    006515               Yogur de avena natural Alpro 500 gr         1
# 47205    006516                Yogur de coco natural Alpro 350 gr         1
# 47206    006518          Yogur vegetal con arandanos Alpro 500 gr         1
# 47207      6499                      Pularda Sanchonar aprox 3 kg     11.84
#
#       Precio_Prod       fecha
# ...

# %%
# Convertir la columna de fecha al formato adecuado
dfventas_2022['fecha'] = pd.to_datetime(dfventas_2022['fecha'], format='%d-%m-%Y')

# %%
dfventas_2022.head(3)
# Out:
#   Id_Prod_2                                        Nom_Prod Cant_Prod  \
# 0    000009                    Aceite coco Maya gold 450 ml         4
# 1    000013   Aceite de girasol Virgen bio Franciscanos 1 L       NaN
# 2    000018  Aceite oliva virgen extra Umbria Oretana 2.5 L         1
#
#   Precio_Prod      fecha
# 0           8 2022-01-31
# 1         NaN 2022-01-31
# 2        18.5 2022-01-31

# %%
# probamos eliminado NAN
dfventas_2022_sin_nan = dfventas_2022

# %%
dfventas_2022_sin_nan= dfventas_2022_sin_nan.dropna()
dfventas_2022_sin_nan.reset_index(inplace=True, drop=True)
dfventas_2022_sin_nan
# Out:
#       Id_Prod_2                                          Nom_Prod Cant_Prod  \
# 0        000009                      Aceite coco Maya gold 450 ml         4
# 1        000018    Aceite oliva virgen extra Umbria Oretana 2.5 L         1
# 2        000020      Aceite oliva virgen extra Umbria oretana 5 L         1
# 3        000021  Aceite oliva virgen extra Umbria oretana 5 L PET         2
# 4        000023  Aceite rosa mosqueta y damáscena Piel sana 50 ml         2
# ...         ...                                               ...       ...
# 31580    006511          Láminas lasagña de sémola Castagno 500 g         2
# 31581    006515               Yogur de avena natural Alpro 500 gr         1
# 31582    006516                Yogur de coco natural Alpro 350 gr         1
# 31583    006518          Yogur vegetal con arandanos Alpro 500 gr         1
# 31584      6499                      Pularda Sanchonar aprox 3 kg     11.84
#
#       Precio_Prod      fecha
# ...

# %%
# probamos reemplazando NaN con cero
dfventas_2022_con_cero = dfventas_2022

# %%
dfventas_2022_con_cero = dfventas_2022_con_cero.fillna(0)
dfventas_2022_con_cero.reset_index(inplace=True, drop=True)
dfventas_2022_con_cero
# Out:
#       Id_Prod_2                                          Nom_Prod  Cant_Prod  \
# 0        000009                      Aceite coco Maya gold 450 ml       4.00
# 1        000013     Aceite de girasol Virgen bio Franciscanos 1 L       0.00
# 2        000018    Aceite oliva virgen extra Umbria Oretana 2.5 L       1.00
# 3        000020      Aceite oliva virgen extra Umbria oretana 5 L       1.00
# 4        000021  Aceite oliva virgen extra Umbria oretana 5 L PET       2.00
# ...         ...                                               ...        ...
# 47203    006511          Láminas lasagña de sémola Castagno 500 g       2.00
# 47204    006515               Yogur de avena natural Alpro 500 gr       1.00
# 47205    006516                Yogur de coco natural Alpro 350 gr       1.00
# 47206    006518          Yogur vegetal con arandanos Alpro 500 gr       1.00
# 47207      6499                      Pularda Sanchonar aprox 3 kg      11.84
#
#        Precio_Prod      fecha
# ...

# %% [markdown]
# ## Proceso para concatenar dfventas_2021 y dfventas_2022

# %%
# Concatenar dataframe
dfventas_2021_2022 = pd.concat([dfventas_2021, dfventas_2022], axis=0)
dfventas_2021_2022.reset_index(inplace=True, drop=True)
dfventas_2021_2022
# Out:
#       Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 0        000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 1        000008  Aceite caléndula y almendras Piel sana 100 ml         2
# 2        000009                   Aceite coco Maya gold 450 ml       NaN
# 3        000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 4        000011       Aceite espliego y rosas Piel sana 100 ml         4
# ...         ...                                            ...       ...
# 93715    006511       Láminas lasagña de sémola Castagno 500 g         2
# 93716    006515            Yogur de avena natural Alpro 500 gr         1
# 93717    006516             Yogur de coco natural Alpro 350 gr         1
# 93718    006518       Yogur vegetal con arandanos Alpro 500 gr         1
# 93719      6499                   Pularda Sanchonar aprox 3 kg     11.84
#
#       Precio_Prod      fecha
# 0             NaN 2021-01-31
# 1            12.5 2021-01-31
# ...

# %%
# OBSERVACION: Se agrega este preoceso porque se identifico Id_Prod_2 con dígitos menores a 6 dígitos.
dfventas_2021_2022.loc[dfventas_2021_2022['Id_Prod_2'].astype(str).str.len() < 6, 'Id_Prod_2'] = dfventas_2021_2022.loc[dfventas_2021_2022['Id_Prod_2'].astype(str).str.len() < 6, 'Id_Prod_2'].astype(str).str.zfill(6)

# %%
dfventas_2021_2022
# Out:
#       Id_Prod_2                                       Nom_Prod Cant_Prod  \
# 0        000007        Aceite árnica y romero Piel sana 100 ml       NaN
# 1        000008  Aceite caléndula y almendras Piel sana 100 ml         2
# 2        000009                   Aceite coco Maya gold 450 ml       NaN
# 3        000010         Aceite desmaquillador Piel sana 100 ml       NaN
# 4        000011       Aceite espliego y rosas Piel sana 100 ml         4
# ...         ...                                            ...       ...
# 93715    006511       Láminas lasagña de sémola Castagno 500 g         2
# 93716    006515            Yogur de avena natural Alpro 500 gr         1
# 93717    006516             Yogur de coco natural Alpro 350 gr         1
# 93718    006518       Yogur vegetal con arandanos Alpro 500 gr         1
# 93719    006499                   Pularda Sanchonar aprox 3 kg     11.84
#
#       Precio_Prod      fecha
# 0             NaN 2021-01-31
# 1            12.5 2021-01-31
# ...

# %%
# OBSERVACIÓN:
# Se verifica que el registro 93719 presenta el Id_Pord_2 con la longitud de 6 dígitos.

# %%
# Probamos eliminado NAN, para obtener un nuevo dataframe dfventas_2021_2022
dfventas_2021_2022_sin_nan = dfventas_2021_2022

# %%
dfventas_2021_2022_sin_nan = dfventas_2021_2022_sin_nan .dropna()
dfventas_2021_2022_sin_nan.reset_index(inplace=True, drop=True)
dfventas_2021_2022_sin_nan
# Out:
#       Id_Prod_2                                           Nom_Prod Cant_Prod  \
# 0        000008      Aceite caléndula y almendras Piel sana 100 ml         2
# 1        000011           Aceite espliego y rosas Piel sana 100 ml         4
# 2        000018     Aceite oliva virgen extra Umbria Oretana 2.5 L         9
# 3        000019  Aceite oliva virgen extra Umbria oretana 500 m...         1
# 4        000020       Aceite oliva virgen extra Umbria oretana 5 L         5
# ...         ...                                                ...       ...
# 60260    006511           Láminas lasagña de sémola Castagno 500 g         2
# 60261    006515                Yogur de avena natural Alpro 500 gr         1
# 60262    006516                 Yogur de coco natural Alpro 350 gr         1
# 60263    006518           Yogur vegetal con arandanos Alpro 500 gr         1
# 60264    006499                       Pularda Sanchonar aprox 3 kg     11.84
#
#       Precio_Prod      fecha
# ...

# %%
# Probamos reemplazando NaN con cero un nuevo dataframe dfventas_2021_2022
dfventas_2021_2022_con_cero = dfventas_2021_2022

# %%
dfventas_2021_2022_con_cero = dfventas_2021_2022_con_cero.fillna(0)
dfventas_2021_2022_con_cero.reset_index(inplace=True, drop=True)
dfventas_2021_2022_con_cero
# Out:
#       Id_Prod_2                                       Nom_Prod  Cant_Prod  \
# 0        000007        Aceite árnica y romero Piel sana 100 ml       0.00
# 1        000008  Aceite caléndula y almendras Piel sana 100 ml       2.00
# 2        000009                   Aceite coco Maya gold 450 ml       0.00
# 3        000010         Aceite desmaquillador Piel sana 100 ml       0.00
# 4        000011       Aceite espliego y rosas Piel sana 100 ml       4.00
# ...         ...                                            ...        ...
# 93715    006511       Láminas lasagña de sémola Castagno 500 g       2.00
# 93716    006515            Yogur de avena natural Alpro 500 gr       1.00
# 93717    006516             Yogur de coco natural Alpro 350 gr       1.00
# 93718    006518       Yogur vegetal con arandanos Alpro 500 gr       1.00
# 93719    006499                   Pularda Sanchonar aprox 3 kg      11.84
#
#        Precio_Prod      fecha
# 0             0.00 2021-01-31
# ...

# %%
# Tenemos los siguientes dataframe limpios, los dos últimos estan imputados (eliminando NaN y reemplazando con cero los datos faltantes)
# dfventas_2021_2022
# dfventas_2021_2022_sin_nan   
# dfventas_2021_2022_con_cero   # IMPUTACION ELEGIDA

# %% [markdown]
# ### Consultas para apoyar el analisis de compras

# %%
# información general de dfventas_2021_2022_con_cero
dfventas_2021_2022_con_cero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93720 entries, 0 to 93719
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id_Prod_2    93720 non-null  object
#  1   Nom_Prod     93720 non-null  object
#  2   Cant_Prod    93720 non-null  float64
#  3   Precio_Prod  93720 non-null  float64
#  4   fecha        93720 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 3.6+ MB

# %%
cc=dfventas_2021_2022_con_cero[dfventas_2021_2022_con_cero.Id_Prod_2=="001637"]  # Se DEBEagregar al Id_Prod_2 el "00" en los datos de los archivos de compras.
cc
# Out:
#       Id_Prod_2          Nom_Prod  Cant_Prod  Precio_Prod      fecha
# 904      001637  Envase Veer 33cl       41.0         0.15 2021-01-31
# 4780     001637  Envase Veer 33cl       65.0         0.15 2021-02-28
# 8656     001637  Envase Veer 33cl       52.0         0.15 2021-03-31
# 12532    001637  Envase Veer 33cl        3.0         0.15 2021-04-30
# 16408    001637  Envase Veer 33cl       83.0         0.15 2021-05-31
# 20284    001637  Envase Veer 33cl       20.0         0.15 2021-06-30
# 24160    001637  Envase Veer 33cl      -14.0         0.15 2021-07-31
# 28036    001637  Envase Veer 33cl      -20.0         0.15 2021-08-31
# 31912    001637  Envase Veer 33cl      -24.0         0.15 2021-09-30
# 35788    001637  Envase Veer 33cl        5.0         0.15 2021-10-31
# 39664    001637  Envase Veer 33cl        7.0         0.15 2021-11-30
# 43540    001637  Envase Veer 33cl       24.0         0.15 2021-12-31
# 47319    001637  Envase Veer 33cl       -5.0         0.15 2022-01-31
# ...

# %%
len(cc)
# Out:
# 24

# %%
# OBSERVACION:
# - El producto "Envase Veer 33cl" es adquirido todos los meses durante los dos años (2021 y 2022)
# - Se observa que en Id_Prod_2 se presneta el cpodigo con 6 dígitos, situación que NO sucede en el archivo de compras,
#   se recomienda agregar 00 a ó la cantidad de dígitos cero que sea necesario para normalizar la variable.
# - Aparentemente se vende al mismo precio que se COMPRA, aún si sacamos un promedio de costo/precio del producto durante los 24 meses.

# %%
# 2do producto para analizar
cc=dfventas_2021_2022_con_cero[dfventas_2021_2022_con_cero.Id_Prod_2=="000597"] 
cc
# Out:
#       Id_Prod_2                       Nom_Prod  Cant_Prod  Precio_Prod  \
# 326      000597  Fuet extra Biobardales 200 gr       11.0         3.90
# 4202     000597  Fuet extra Biobardales 200 gr       17.0         3.90
# 8078     000597  Fuet extra Biobardales 200 gr       16.0         3.90
# 11954    000597  Fuet extra Biobardales 200 gr       23.0         3.90
# 15830    000597  Fuet extra Biobardales 200 gr       15.0         3.90
# 19706    000597  Fuet extra Biobardales 200 gr       17.0         3.90
# 23582    000597  Fuet extra Biobardales 200 gr       11.0         3.90
# 27458    000597  Fuet extra Biobardales 200 gr       10.0         3.90
# 31334    000597  Fuet extra Biobardales 200 gr        8.0         3.90
# 35210    000597  Fuet extra Biobardales 200 gr       17.0         3.90
# 39086    000597  Fuet extra Biobardales 200 gr        3.0         3.90
# 42962    000597  Fuet extra Biobardales 200 gr       12.0         3.90
# ...

# %%
len(cc)
# Out:
# 24

# %%
# OBSERVACION:
# - El producto es adquirido todos los meses durante los dos años (2021 y 2022), pero el precio de compra y venta varia.
# - Sacar el promedio sí nos dará resultados favorables para analisis de inflación.

# %%
# Vamos a proceder a limitar la fecha con mes y año

# Primero ordenamos por fecha.
dfventas_2021_2022_con_cero.sort_values(by='fecha')  

# se define el formato fecha por año y mes porque se requiere promedios mensuales
dfventas_2021_2022_con_cero['Fecha_Venta'] = pd.PeriodIndex(dfventas_2021_2022_con_cero['fecha'], freq='M')
dfventas_2021_2022_con_cero
# Out:
#       Id_Prod_2                                       Nom_Prod  Cant_Prod  \
# 0        000007        Aceite árnica y romero Piel sana 100 ml       0.00
# 1        000008  Aceite caléndula y almendras Piel sana 100 ml       2.00
# 2        000009                   Aceite coco Maya gold 450 ml       0.00
# 3        000010         Aceite desmaquillador Piel sana 100 ml       0.00
# 4        000011       Aceite espliego y rosas Piel sana 100 ml       4.00
# ...         ...                                            ...        ...
# 93715    006511       Láminas lasagña de sémola Castagno 500 g       2.00
# 93716    006515            Yogur de avena natural Alpro 500 gr       1.00
# 93717    006516             Yogur de coco natural Alpro 350 gr       1.00
# 93718    006518       Yogur vegetal con arandanos Alpro 500 gr       1.00
# 93719    006499                   Pularda Sanchonar aprox 3 kg      11.84
#
#        Precio_Prod      fecha Fecha_Venta
# ...

# %%
dfventas_2021_2022_con_cero_V2 = dfventas_2021_2022_con_cero.drop('fecha',axis=1)
dfventas_2021_2022_con_cero_V2
# Out:
#       Id_Prod_2                                       Nom_Prod  Cant_Prod  \
# 0        000007        Aceite árnica y romero Piel sana 100 ml       0.00
# 1        000008  Aceite caléndula y almendras Piel sana 100 ml       2.00
# 2        000009                   Aceite coco Maya gold 450 ml       0.00
# 3        000010         Aceite desmaquillador Piel sana 100 ml       0.00
# 4        000011       Aceite espliego y rosas Piel sana 100 ml       4.00
# ...         ...                                            ...        ...
# 93715    006511       Láminas lasagña de sémola Castagno 500 g       2.00
# 93716    006515            Yogur de avena natural Alpro 500 gr       1.00
# 93717    006516             Yogur de coco natural Alpro 350 gr       1.00
# 93718    006518       Yogur vegetal con arandanos Alpro 500 gr       1.00
# 93719    006499                   Pularda Sanchonar aprox 3 kg      11.84
#
#        Precio_Prod Fecha_Venta
# 0             0.00     2021-01
# ...

# %%
# Convertir 'Fecha_Compra' a tipo datetime y extraer año y mes

dfventas_2021_2022_con_cero_V2['Año_Venta'] = dfventas_2021_2022_con_cero_V2['Fecha_Venta'].dt.year
dfventas_2021_2022_con_cero_V2['Mes_Venta'] = dfventas_2021_2022_con_cero_V2['Fecha_Venta'].dt.month
# Mostrar resultado
dfventas_2021_2022_con_cero_V2
# Out:
#       Id_Prod_2                                       Nom_Prod  Cant_Prod  \
# 0        000007        Aceite árnica y romero Piel sana 100 ml       0.00
# 1        000008  Aceite caléndula y almendras Piel sana 100 ml       2.00
# 2        000009                   Aceite coco Maya gold 450 ml       0.00
# 3        000010         Aceite desmaquillador Piel sana 100 ml       0.00
# 4        000011       Aceite espliego y rosas Piel sana 100 ml       4.00
# ...         ...                                            ...        ...
# 93715    006511       Láminas lasagña de sémola Castagno 500 g       2.00
# 93716    006515            Yogur de avena natural Alpro 500 gr       1.00
# 93717    006516             Yogur de coco natural Alpro 350 gr       1.00
# 93718    006518       Yogur vegetal con arandanos Alpro 500 gr       1.00
# 93719    006499                   Pularda Sanchonar aprox 3 kg      11.84
#
#        Precio_Prod Fecha_Venta  Año_Venta  Mes_Venta
# ...

# %%
#dfventas_2021_2022_con_cero_V2 = dfventas_2021_2022_con_cero_V2.drop('Fecha_Venta',axis=1)
#dfventas_2021_2022_con_cero_V2

# %%
# Renombramos el df ventas a dfosa_ventas
dfosa_ventas=dfventas_2021_2022_con_cero_V2
dfosa_ventas
# Out:
#       Id_Prod_2                                       Nom_Prod  Cant_Prod  \
# 0        000007        Aceite árnica y romero Piel sana 100 ml       0.00
# 1        000008  Aceite caléndula y almendras Piel sana 100 ml       2.00
# 2        000009                   Aceite coco Maya gold 450 ml       0.00
# 3        000010         Aceite desmaquillador Piel sana 100 ml       0.00
# 4        000011       Aceite espliego y rosas Piel sana 100 ml       4.00
# ...         ...                                            ...        ...
# 93715    006511       Láminas lasagña de sémola Castagno 500 g       2.00
# 93716    006515            Yogur de avena natural Alpro 500 gr       1.00
# 93717    006516             Yogur de coco natural Alpro 350 gr       1.00
# 93718    006518       Yogur vegetal con arandanos Alpro 500 gr       1.00
# 93719    006499                   Pularda Sanchonar aprox 3 kg      11.84
#
#        Precio_Prod Fecha_Venta  Año_Venta  Mes_Venta
# ...

# %% [markdown]
# ## EDA COMPRAS

# %%
# Datasets de compra de productos a proveedores 2021-2022
# precio_enejun= pd.read_excel("Evolución_precio_enerojunio22.xls")  # Archivo 1
# precio_juldic= pd.read_excel("Evolución_precio_juliodiciembre22.xls") # Obs: columna fecha con mes dic duplicada con el dataframe precio_2022 # Archivo 2
# precio_2021= pd.read_excel("Price_history_2021.xls")         # Archivo 3
# precio_2022= pd.read_excel("Price_history_122022.xls")       # Archivo 4

# %%
# Explorando archivo 1 de compras
precio_enejun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33361 entries, 0 to 33360
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             21005 non-null  object
#  1   Producto/Nombre                                         21005 non-null  object
#  2   Coste                                                   21005 non-null  float64
#  3   Fecha                                                   21005 non-null  datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  21005 non-null  object
#  5   Producto/Referencia interna                             21005 non-null  float64
#  6   Producto/Proveedores/Nombre a mostrar                   33361 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         21005 non-null  object
# ...

# %%
precio_enejun
# Out:
#                                            External ID  \
# 0      __export__.product_price_history_78926_abded360
# 1      __export__.product_price_history_78925_30713b35
# 2      __export__.product_price_history_78916_73aa1b21
# 3      __export__.product_price_history_78919_197ec6c0
# 4      __export__.product_price_history_78918_c43ac4cb
# ...                                                ...
# 33356  __export__.product_price_history_57476_a123a605
# 33357  __export__.product_price_history_57475_01d2b4c1
# 33358  __export__.product_price_history_57473_9223a116
# 33359  __export__.product_price_history_57474_6d53100b
# 33360  __export__.product_price_history_57472_e1e9d62e
#
#                                          Producto/Nombre  Coste  \
# 0                                       Envase Veer 33cl   0.15
# 1                                       Envase Veer 33cl   0.15
# 2                          Fuet extra Biobardales 200 gr   2.95
# ...

# %%
# Explorando archivo 2 de compras
precio_juldic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             16217 non-null  object
#  1   Producto/Nombre                                         16217 non-null  object
#  2   Coste                                                   16217 non-null  float64
#  3   Fecha                                                   16217 non-null  datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  16217 non-null  object
#  5   Producto/Referencia interna                             16217 non-null  float64
#  6   Producto/Proveedores/Nombre a mostrar                   24783 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         16217 non-null  object
# ...

# %%
precio_juldic
# Out:
#                                            External ID  \
# 0      __export__.product_price_history_95321_35282e65
# 1      __export__.product_price_history_95315_6718a328
# 2      __export__.product_price_history_95314_e5481612
# 3      __export__.product_price_history_95313_1e7ac49b
# 4      __export__.product_price_history_95312_1fbab516
# ...                                                ...
# 24778  __export__.product_price_history_78928_ebc91b42
# 24779                                              NaN
# 24780                                              NaN
# 24781                                              NaN
# 24782  __export__.product_price_history_78927_9cdb8c96
#
#                                    Producto/Nombre  Coste               Fecha  \
# 0                Barrita de sésamo bio Ideas 20 gr   0.26 2022-12-14 12:37:50
# 1         Crema de cacahuete bio Ethiquable 350 gr   3.63 2022-12-14 12:37:50
# ...

# %%
# Explorando archivo 3 de compras
precio_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57558 entries, 0 to 57557
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             37023 non-null  object
#  1   Producto/Nombre                                         37023 non-null  object
#  2   Coste                                                   37023 non-null  float64
#  3   Fecha                                                   37023 non-null  datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  37023 non-null  object
#  5   Producto/Referencia interna                             37023 non-null  float64
#  6   Producto/Proveedores/Nombre a mostrar                   57558 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         37023 non-null  object
# ...

# %%
precio_2021
# Out:
#                                            External ID  \
# 0      __export__.product_price_history_57358_1e54992d
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 57553  __export__.product_price_history_17321_030fc96e
# 57554  __export__.product_price_history_17319_e9e33a8c
# 57555  __export__.product_price_history_17317_607ad568
# 57556  __export__.product_price_history_17316_a7765be4
# 57557  __export__.product_price_history_17315_175465d1
#
#                                        Producto/Nombre  Coste  \
# 0                                   Manzana royal gala   1.53
# 1                                                  NaN    NaN
# 2                                                  NaN    NaN
# ...

# %%
# Explorando archivo 4 de compras
precio_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4254 entries, 0 to 4253
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             2809 non-null   object
#  1   Producto/Nombre                                         2809 non-null   object
#  2   Coste                                                   2809 non-null   float64
#  3   Fecha                                                   2809 non-null   datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  2809 non-null   object
#  5   Producto/Referencia interna                             2809 non-null   float64
#  6   Producto/Proveedores/Nombre a mostrar                   4254 non-null   object
#  7   Producto/Categoría de producto/Nombre a mostrar         2809 non-null   object
# ...

# %%
precio_2022.head(3000)
# Out:
#                                           External ID  \
# 0     __export__.product_price_history_96984_4bf1bf39
# 1                                                 NaN
# 2     __export__.product_price_history_96985_0c0a24a8
# 3                                                 NaN
# 4     __export__.product_price_history_96965_065bfbca
# ...                                               ...
# 2995  __export__.product_price_history_94978_d77c568f
# 2996  __export__.product_price_history_94977_43969991
# 2997  __export__.product_price_history_94976_5187a60d
# 2998  __export__.product_price_history_94975_ce4902cc
# 2999  __export__.product_price_history_94974_a674f3b2
#
#                                         Producto/Nombre  Coste  \
# 0     Yogur desnatado vainilla Casa grande xanceda 2...   1.45
# 1                                                   NaN    NaN
# 2     Queso eco peregrino producción limitada Casa G...   7.70
# ...

# %%
# Analizando los 4 archivos de compras, se debe realizar lo siguiente:
# 1. Fusionar los 4 archivos en uno solo.
# 2. Con respecto al archivo duplicado del mes de Dic_2022, al ser fusinado se podrá eliminar los registros duplicados.
# 3. Eliminar "External ID"
# 4. Eliminar la hora de la columna fecha.
# 5. Agregarle digitos 0 (ceros) al "Producto/Referencia interna" hasta completar los 6 dígitos (normalización). 
#    Pero primero se debe eliminar los campos con valor NULO para poder aplicar las funciones necesarias.
# 6. Por el momento NO es recomendable subcategorizar los productos en base a "Producto/Categoría de producto/Nombre a mostrar"
#    porque existirán productos con nombres extraños que no podremos identificar para determinar su categoría.
#    En una segunda versión, quizás se pueda filtrar el primer nombre para poder establecer una subcategoría.
# 7. Renombrar los campos, priorizando o alineando los nombre asignados en los dfventas. Revisando los dfcompras se recomienda:
#    "Producto/Cuenta analítica para gastos/Nombre a mostrar" por TIPO_PRODUCTO
#    "Producto/Proveedores/Nombre a mostrar" por PROVEEDOR
#    "Producto/Categoría de producto/Nombre a mostrar" por CATEGORIA_PRODUCTO

# %%
# Explorando.
# El dataframe precio_2022 contiene registros de compras de fecha sólo del mes de DICIEMBRE
# renombrar a precio_julio_2022
precio_dic_2022=precio_2022
precio_dic_2022
# Out:
#                                           External ID  \
# 0     __export__.product_price_history_96984_4bf1bf39
# 1                                                 NaN
# 2     __export__.product_price_history_96985_0c0a24a8
# 3                                                 NaN
# 4     __export__.product_price_history_96965_065bfbca
# ...                                               ...
# 4249                                              NaN
# 4250                                              NaN
# 4251  __export__.product_price_history_94161_7fe055d2
# 4252                                              NaN
# 4253                                              NaN
#
#                                         Producto/Nombre  Coste  \
# 0     Yogur desnatado vainilla Casa grande xanceda 2...   1.45
# 1                                                   NaN    NaN
# 2     Queso eco peregrino producción limitada Casa G...   7.70
# ...

# %%
# Reportar la cantidad NaN en precio_dic_2022
precio_dic_2022_producto_con_nan = precio_dic_2022['Producto/Nombre'].isna().sum()
precio_dic_2022_producto_con_nan
# Out:
# 1445

# %%
# Porcentaje de valores NaN
percent_nan = precio_dic_2022['Producto/Nombre'].isna().mean() * 100
percent_nan
# Out:
# 33.9680300893277

# %%
# OBSERVACION:
# En el df precio_dic_2022 se tiene un 33.968% de valores nulos.
# Considerar este dato para comparar el porcentaje de NaN al fucionar los df donde aparecne duplicados el mes de dicimebre del 2022.

# %%
# Probar, que apsaría si eliminamos los registros que presnetan NaN en producto
precio_dic_2022_sin_nan=precio_dic_2022.dropna(subset=['Producto/Nombre'])
precio_dic_2022_sin_nan
# Out:
#                                           External ID  \
# 0     __export__.product_price_history_96984_4bf1bf39
# 2     __export__.product_price_history_96985_0c0a24a8
# 4     __export__.product_price_history_96965_065bfbca
# 5     __export__.product_price_history_96966_2aa62eac
# 7     __export__.product_price_history_96967_56dcb008
# ...                                               ...
# 4241  __export__.product_price_history_94170_f95b7cbd
# 4243  __export__.product_price_history_94169_a01653b4
# 4244  __export__.product_price_history_94168_bcb8bdd9
# 4248  __export__.product_price_history_94162_03b9ec8a
# 4251  __export__.product_price_history_94161_7fe055d2
#
#                                         Producto/Nombre  Coste  \
# 0     Yogur desnatado vainilla Casa grande xanceda 2...   1.45
# 2     Queso eco peregrino producción limitada Casa G...   7.70
# 4     Yogur griego con stracciatella pack 2 Casa gra...   1.45
# ...

# %%
len(precio_dic_2022_sin_nan)
# Out:
# 2809

# %%
# El df precio_dic_2022_sin_nan presenta 2809 registros, es una cantidad mayor a lo sregistros del
# dfprecio_juldic_diciembre_2022 que presenta una cantida de 1155 registros.
# Se recomienda fusionar ambos registros e liminar los duplicados.

# %%
# Explorando df precio_juldic
# Analizando el dataframe precio_juldic para verificar si las compras de diciembre 2022 son iguales o 
# cual dataframe presenta menos valores NaN

# %%
# Creamos un nuevo df con registros del mes de diciembre de 2022 tomando como base el df precio_juldic

# Convertimos la columna de fecha a un objeto datetime
precio_juldic['Fecha_dic'] = pd.to_datetime(precio_juldic['Fecha'])

# Filtramos los registros del mes de diciembre
dfprecio_juldic_diciembre_2022 = precio_juldic[precio_juldic['Fecha_dic'].dt.month == 12]

dfprecio_juldic_diciembre_2022
# Out:
#                                           External ID  \
# 0     __export__.product_price_history_95321_35282e65
# 1     __export__.product_price_history_95315_6718a328
# 2     __export__.product_price_history_95314_e5481612
# 3     __export__.product_price_history_95313_1e7ac49b
# 4     __export__.product_price_history_95312_1fbab516
# ...                                               ...
# 1787  __export__.product_price_history_94175_9a4dfe59
# 1788  __export__.product_price_history_94174_261a8c7c
# 1792  __export__.product_price_history_94173_b76eab84
# 1796  __export__.product_price_history_94172_14cdf0a0
# 1800  __export__.product_price_history_94161_7fe055d2
#
#                                   Producto/Nombre  Coste               Fecha  \
# 0               Barrita de sésamo bio Ideas 20 gr   0.26 2022-12-14 12:37:50
# 1        Crema de cacahuete bio Ethiquable 350 gr   3.63 2022-12-14 12:37:50
# 2     Caramelos cereza y jengibre bio Ideas 100 g   1.66 2022-12-14 12:37:50
# ...

# %%
# Reportar la cantidad NaN en dfprecio_juldic_diciembre_2022
dfprecio_juldic_diciembre_2022_producto_con_nan = dfprecio_juldic_diciembre_2022['Producto/Nombre'].isna().sum()
dfprecio_juldic_diciembre_2022_producto_con_nan
# Out:
# 0

# %%
precio_juldic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 9 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             16217 non-null  object
#  1   Producto/Nombre                                         16217 non-null  object
#  2   Coste                                                   16217 non-null  float64
#  3   Fecha                                                   16217 non-null  datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  16217 non-null  object
#  5   Producto/Referencia interna                             16217 non-null  float64
#  6   Producto/Proveedores/Nombre a mostrar                   24783 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         16217 non-null  object
# ...

# %%
# OBSERVACIÓN:
# Se generó la columan FEcha_dic adicional por el preocedimiento anterior, se debe proceder a eliminarlo para NO
# tener conflicto al juntar los 4 df.
precio_juldic = precio_juldic.drop('Fecha_dic', axis=1)
precio_juldic
# Out:
#                                            External ID  \
# 0      __export__.product_price_history_95321_35282e65
# 1      __export__.product_price_history_95315_6718a328
# 2      __export__.product_price_history_95314_e5481612
# 3      __export__.product_price_history_95313_1e7ac49b
# 4      __export__.product_price_history_95312_1fbab516
# ...                                                ...
# 24778  __export__.product_price_history_78928_ebc91b42
# 24779                                              NaN
# 24780                                              NaN
# 24781                                              NaN
# 24782  __export__.product_price_history_78927_9cdb8c96
#
#                                    Producto/Nombre  Coste               Fecha  \
# 0                Barrita de sésamo bio Ideas 20 gr   0.26 2022-12-14 12:37:50
# 1         Crema de cacahuete bio Ethiquable 350 gr   3.63 2022-12-14 12:37:50
# ...

# %% [markdown]
# ### 1. Fisionamos los 4 dataframe

# %%
# Fusionamos las compras de los años 2021 y 2022
# precio_enejun= pd.read_excel("Evolución_precio_enerojunio22.xls")  # Archivo 1
# precio_juldic= pd.read_excel("Evolución_precio_juliodiciembre22.xls") # Obs: columna fecha con mes dic duplicada con el dataframe precio_2022 # Archivo 2
# precio_2021= pd.read_excel("Price_history_2021.xls")         # Archivo 3
# precio_2022= pd.read_excel("Price_history_122022.xls")       # Archivo 4

# %%
# Fusionamos los dataframes consideradno el orden por año (2021 y 2022)
dfcompras_2021_2022= pd.concat([precio_2021, precio_enejun, precio_juldic, precio_2022], axis=0)

# Mostramos el resultado
dfcompras_2021_2022
# Out:
#                                           External ID      Producto/Nombre  \
# 0     __export__.product_price_history_57358_1e54992d   Manzana royal gala
# 1                                                 NaN                  NaN
# 2                                                 NaN                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# ...                                               ...                  ...
# 4249                                              NaN                  NaN
# 4250                                              NaN                  NaN
# 4251  __export__.product_price_history_94161_7fe055d2  Kiwi verde nacional
# 4252                                              NaN                  NaN
# 4253                                              NaN                  NaN
#
#       Coste               Fecha  \
# 0      1.53 2021-12-30 18:51:57
# ...

# %%
dfcompras_2021_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119956 entries, 0 to 4253
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count   Dtype
# ---  ------                                                  --------------   -----
#  0   External ID                                             77054 non-null   object
#  1   Producto/Nombre                                         77054 non-null   object
#  2   Coste                                                   77054 non-null   float64
#  3   Fecha                                                   77054 non-null   datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  77054 non-null   object
#  5   Producto/Referencia interna                             77054 non-null   float64
#  6   Producto/Proveedores/Nombre a mostrar                   119956 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         77054 non-null   object
# ...

# %% [markdown]
# ### Eliminar duplicados

# %%
# 2. Con respecto al archivo duplicado del mes de Dic_2022, al ser fusinado se podrá eliminar los registros duplicados.

# %%
# Se elimina registros duplicados y se asgna a un nuevo df
dfcompras_2021_2022_sin_dupli = dfcompras_2021_2022.drop_duplicates()
dfcompras_2021_2022_sin_dupli
# Out:
#                                           External ID     Producto/Nombre  \
# 0     __export__.product_price_history_57358_1e54992d  Manzana royal gala
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# ...                                               ...                 ...
# 4220  __export__.product_price_history_94166_365b75ee              Pomelo
# 4230  __export__.product_price_history_94173_b76eab84         Tomate pera
# 4234  __export__.product_price_history_94172_14cdf0a0       Tomate cherry
# 4238  __export__.product_price_history_94171_53e459e3      Cebolla Blanca
# 4248  __export__.product_price_history_94162_03b9ec8a           Mandarina
#
#       Coste               Fecha  \
# 0      1.53 2021-12-30 18:51:57
# ...

# %%
dfcompras_2021_2022_sin_dupli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76053 entries, 0 to 4248
# Data columns (total 8 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   External ID                                             76018 non-null  object
#  1   Producto/Nombre                                         76018 non-null  object
#  2   Coste                                                   76018 non-null  float64
#  3   Fecha                                                   76018 non-null  datetime64[ns]
#  4   Producto/Cuenta analítica para gastos/Nombre a mostrar  76018 non-null  object
#  5   Producto/Referencia interna                             76018 non-null  float64
#  6   Producto/Proveedores/Nombre a mostrar                   76053 non-null  object
#  7   Producto/Categoría de producto/Nombre a mostrar         76018 non-null  object
# ...

# %%
# Calcular la cantidaad de elementos duplicados que fueron eliminados
cant_reg_eliminados_1=len(dfcompras_2021_2022)-len(dfcompras_2021_2022_sin_dupli)
cant_reg_eliminados_1
# Out:
# 43903

# %%
# SE eliminarosn 43903 registros.

# %% [markdown]
# ### Eliminar columnas innecesarias

# %%
# 3. Eliminar "External ID"
# Primero visualizamos las columnas, para ver como estan configuradas
print(dfcompras_2021_2022_sin_dupli.columns)
# Out:
# Index(['External ID', 'Producto/Nombre', 'Coste', 'Fecha',
#        'Producto/Cuenta analítica para gastos/Nombre a mostrar',
#        'Producto/Referencia interna', 'Producto/Proveedores/Nombre a mostrar',
#        'Producto/Categoría de producto/Nombre a mostrar'],
#       dtype='object')

# %%
# Segundo, eliminamos columna "External ID"
dfcompras_2021_2022_V2 = dfcompras_2021_2022_sin_dupli.drop('External ID', axis=1)
dfcompras_2021_2022_V2
# Out:
#          Producto/Nombre  Coste               Fecha  \
# 0     Manzana royal gala   1.53 2021-12-30 18:51:57
# 1                    NaN    NaN                 NaT
# 2                    NaN    NaN                 NaT
# 3                    NaN    NaN                 NaT
# 4                    NaN    NaN                 NaT
# ...                  ...    ...                 ...
# 4220              Pomelo   1.38 2022-12-01 07:53:53
# 4230         Tomate pera   1.44 2022-12-01 07:53:53
# 4234       Tomate cherry   2.08 2022-12-01 07:53:53
# 4238      Cebolla Blanca   0.92 2022-12-01 07:53:53
# 4248           Mandarina   1.66 2022-12-01 07:53:53
#
#      Producto/Cuenta analítica para gastos/Nombre a mostrar  \
# 0                                                   Eco
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
dfcompras_2021_2022_V2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76053 entries, 0 to 4248
# Data columns (total 7 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Producto/Nombre                                         76018 non-null  object
#  1   Coste                                                   76018 non-null  float64
#  2   Fecha                                                   76018 non-null  datetime64[ns]
#  3   Producto/Cuenta analítica para gastos/Nombre a mostrar  76018 non-null  object
#  4   Producto/Referencia interna                             76018 non-null  float64
#  5   Producto/Proveedores/Nombre a mostrar                   76053 non-null  object
#  6   Producto/Categoría de producto/Nombre a mostrar         76018 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 4.6+ MB

# %% [markdown]
# ### Eliminar la hora

# %%
# 4. Eliminar la hora de la columna fecha.
dfcompras_2021_2022_V2['Fecha'] = dfcompras_2021_2022_V2['Fecha'].dt.date
dfcompras_2021_2022_V2
# Out:
#          Producto/Nombre  Coste       Fecha  \
# 0     Manzana royal gala   1.53  2021-12-30
# 1                    NaN    NaN         NaT
# 2                    NaN    NaN         NaT
# 3                    NaN    NaN         NaT
# 4                    NaN    NaN         NaT
# ...                  ...    ...         ...
# 4220              Pomelo   1.38  2022-12-01
# 4230         Tomate pera   1.44  2022-12-01
# 4234       Tomate cherry   2.08  2022-12-01
# 4238      Cebolla Blanca   0.92  2022-12-01
# 4248           Mandarina   1.66  2022-12-01
#
#      Producto/Cuenta analítica para gastos/Nombre a mostrar  \
# 0                                                   Eco
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# ...

# %%
dfcompras_2021_2022_V2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76053 entries, 0 to 4248
# Data columns (total 7 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Producto/Nombre                                         76018 non-null  object
#  1   Coste                                                   76018 non-null  float64
#  2   Fecha                                                   76018 non-null  object
#  3   Producto/Cuenta analítica para gastos/Nombre a mostrar  76018 non-null  object
#  4   Producto/Referencia interna                             76018 non-null  float64
#  5   Producto/Proveedores/Nombre a mostrar                   76053 non-null  object
#  6   Producto/Categoría de producto/Nombre a mostrar         76018 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 4.6+ MB

# %%
# Convertir el tipo de dato de Fecha de object a datetime64
dfcompras_2021_2022_V2['Fecha'] = pd.to_datetime(dfcompras_2021_2022_V2['Fecha']).dt.date
dfcompras_2021_2022_V2.head(20000)
# Out:
#                                          Producto/Nombre  Coste       Fecha  \
# 0                                     Manzana royal gala   1.53  2021-12-30
# 1                                                    NaN    NaN         NaT
# 2                                                    NaN    NaN         NaT
# 3                                                    NaN    NaN         NaT
# 4                                                    NaN    NaN         NaT
# ...                                                  ...    ...         ...
# 31305         Crema almendra tostada bio Rapunzel 250 gr   5.30  2021-06-17
# 31306  Galleta con copos de avena integral con chips ...   1.71  2021-06-17
# 31307          Lavavajillas hipoalergénico 0% Ecodoo 1 L   2.42  2021-06-17
# 31308                     Wafel de caramelo Biocop 175 g   1.48  2021-06-17
# 31309  Galletas trigo espelta integral chocolate y av...   1.74  2021-06-17
#
# ...

# %% [markdown]
# ### Normalizar la cantidad de dígitos del código de producto.

# %%
# 5. Agregarle digitos 0 (ceros) al "Producto/Referencia interna" hasta completar los 6 dígitos (normalización).
#    Pero primero se debe eliminar los campos con valor NULO para poder aplicar las funciones necesarias.

# %%
dfcompras_2021_2022_V2 = dfcompras_2021_2022_V2.dropna(subset=['Producto/Referencia interna'])
dfcompras_2021_2022_V2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76018 entries, 0 to 4248
# Data columns (total 7 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Producto/Nombre                                         76018 non-null  object
#  1   Coste                                                   76018 non-null  float64
#  2   Fecha                                                   76018 non-null  object
#  3   Producto/Cuenta analítica para gastos/Nombre a mostrar  76018 non-null  object
#  4   Producto/Referencia interna                             76018 non-null  float64
#  5   Producto/Proveedores/Nombre a mostrar                   76018 non-null  object
#  6   Producto/Categoría de producto/Nombre a mostrar         76018 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 4.6+ MB

# %%
dfcompras_2021_2022_V2
# Out:
#                                         Producto/Nombre  Coste       Fecha  \
# 0                                    Manzana royal gala   1.53  2021-12-30
# 5                                           Tomate rama   2.31  2021-12-30
# 9                         Recambio cepillo suave Yaweco   4.06  2021-12-30
# 10                  Recambio cepillo medium hard Yaweco   4.06  2021-12-30
# 11    Mini guantes de algodón bio reutilizables Anae...   4.30  2021-12-30
# ...                                                 ...    ...         ...
# 4220                                             Pomelo   1.38  2022-12-01
# 4230                                        Tomate pera   1.44  2022-12-01
# 4234                                      Tomate cherry   2.08  2022-12-01
# 4238                                     Cebolla Blanca   0.92  2022-12-01
# 4248                                          Mandarina   1.66  2022-12-01
#
#      Producto/Cuenta analítica para gastos/Nombre a mostrar  \
# ...

# %%
# Convertir a valor entero.
dfcompras_2021_2022_V2['Producto/Referencia interna'] = dfcompras_2021_2022_V2['Producto/Referencia interna'].astype(int)
dfcompras_2021_2022_V2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76018 entries, 0 to 4248
# Data columns (total 7 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Producto/Nombre                                         76018 non-null  object
#  1   Coste                                                   76018 non-null  float64
#  2   Fecha                                                   76018 non-null  object
#  3   Producto/Cuenta analítica para gastos/Nombre a mostrar  76018 non-null  object
#  4   Producto/Referencia interna                             76018 non-null  int64
#  5   Producto/Proveedores/Nombre a mostrar                   76018 non-null  object
#  6   Producto/Categoría de producto/Nombre a mostrar         76018 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 4.6+ MB

# %%
dfcompras_2021_2022_V2.loc[dfcompras_2021_2022_V2['Producto/Referencia interna'].astype(str).str.len() < 6, 'Producto/Referencia interna'] = dfcompras_2021_2022_V2.loc[dfcompras_2021_2022_V2['Producto/Referencia interna'].astype(str).str.len() < 6, 'Producto/Referencia interna'].astype(str).str.zfill(6)

# %%
dfcompras_2021_2022_V2.head(60000)
# Out:
#                                         Producto/Nombre  Coste       Fecha  \
# 0                                    Manzana royal gala   1.53  2021-12-30
# 5                                           Tomate rama   2.31  2021-12-30
# 9                         Recambio cepillo suave Yaweco   4.06  2021-12-30
# 10                  Recambio cepillo medium hard Yaweco   4.06  2021-12-30
# 11    Mini guantes de algodón bio reutilizables Anae...   4.30  2021-12-30
# ...                                                 ...    ...         ...
# 2955                           Habas baby Gourmet 425 g   1.49  2022-11-24
# 2956                Tomate entero pelado Gourmet 480 gr   0.84  2022-11-24
# 2957                    Tomate triturado Gourmet 800 gr   0.84  2022-11-24
# 2958                    Tomate triturado Gourmet 400 gr   0.53  2022-11-24
# 2959              Judia verde fina redonda Gourmet 420g   1.14  2022-11-24
#
#      Producto/Cuenta analítica para gastos/Nombre a mostrar  \
# ...

# %%
### NO es recomendable subcategorizar los productos

# %%
# 6. Por el momento NO es recomendable subcategorizar los productos en base a "Producto/Categoría de producto/Nombre a mostrar"
#    porque existirán productos con nombres extraños que no podremos identificar para determinar su categoría.
#    En una segunda versión, quizás se pueda filtrar el primer nombre para poder establecer una subcategoría.

# %%
### Renombrar columnas

# %%
# 7. Renombrar los campos, priorizando o alineando los nombre asignados en los dfventas. Revisando los dfcompras, se recomienda:
#    "Producto/Cuenta analítica para gastos/Nombre a mostrar" por TIPO_PRODUCTO
#    "Producto/Proveedores/Nombre a mostrar" por PROVEEDOR
#    "Producto/Categoría de producto/Nombre a mostrar" por CATEGORIA_PRODUCTO

dfcompras_2021_2022_V2 = dfcompras_2021_2022_V2.rename(columns={
    'Producto/Nombre': 'Nombre_Prod',
    'Coste': 'Costo_Compra',
    'Fecha': 'Fecha_Compra',
    'Producto/Cuenta analítica para gastos/Nombre a mostrar': 'Tipo_Prod',
    'Producto/Referencia interna': 'Id_Prod_2',
    'Producto/Proveedores/Nombre a mostrar': 'Proveedor',
    'Producto/Categoría de producto/Nombre a mostrar': 'Categoria_Prod'
})

# %%
dfcompras_2021_2022_V2
# Out:
#                                             Nombre_Prod  Costo_Compra  \
# 0                                    Manzana royal gala          1.53
# 5                                           Tomate rama          2.31
# 9                         Recambio cepillo suave Yaweco          4.06
# 10                  Recambio cepillo medium hard Yaweco          4.06
# 11    Mini guantes de algodón bio reutilizables Anae...          4.30
# ...                                                 ...           ...
# 4220                                             Pomelo          1.38
# 4230                                        Tomate pera          1.44
# 4234                                      Tomate cherry          2.08
# 4238                                     Cebolla Blanca          0.92
# 4248                                          Mandarina          1.66
#
#      Fecha_Compra     Tipo_Prod Id_Prod_2  \
# 0      2021-12-30           Eco    000921
# ...

# %%
dfcompras_2021_2022_V2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76018 entries, 0 to 4248
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre_Prod     76018 non-null  object
#  1   Costo_Compra    76018 non-null  float64
#  2   Fecha_Compra    76018 non-null  object
#  3   Tipo_Prod       76018 non-null  object
#  4   Id_Prod_2       76018 non-null  object
#  5   Proveedor       76018 non-null  object
#  6   Categoria_Prod  76018 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 4.6+ MB

# %%
# Visualizar los valores unicos de la Categoria_Prod
valores_unicos_1 = dfcompras_2021_2022_V2['Categoria_Prod'].unique()
print(valores_unicos_1)
# Out:
# ['Fruta y Verdura / Fruta / Fruta de pepita'
#  'Fruta y Verdura / Verdura / Verdura de cocinar'
#  'Droguería, Perfumería, Limpieza, Higiene, Hogar / Higiene / Higiene bucal'
#  'Droguería, Perfumería, Limpieza, Higiene, Hogar / Higiene / Higiene corporal'
#  'Droguería, Perfumería, Limpieza, Higiene, Hogar / Parafarmacia y cosmética / Cuidado de la piel'
#  'Seco Envasado / Dulces y repostería / Otros'
#  'Droguería, Perfumería, Limpieza, Higiene, Hogar / Droguería / Acccesorios de limpieza'
#  'Droguería, Perfumería, Limpieza, Higiene, Hogar / Droguería / Productos de limpieza'
#  'Droguería, Perfumería, Limpieza, Higiene, Hogar / Hogar / Pilas'
#  'Seco Envasado / Dulces y repostería / Conservas de frutas'
#  'Seco Envasado / Panes, harinas / Panes industriales'
#  'Droguería, Perfumería, Limpieza, Higiene, Hogar / Droguería / Jabón y detergente'
#  'Seco Envasado / Desayunos y merienda / Galletas'
#  'Seco Envasado / Desayunos y merienda / Cereales'
# ...

# %%
# Visualizar los valores unicos 
valores_unicos_2 = dfcompras_2021_2022_V2['Nombre_Prod'].unique()
valores_unicos_2
# Out:
# array(['Manzana royal gala', 'Tomate rama',
#        'Recambio cepillo suave Yaweco', ...,
#        'Conejo escabechado VACÍO combinado 1 ración',
#        'Pollo entero deshuesado Sanchonar aprox 2,5 kg',
#        'Pollo capón deshuesado  Sanchonar aprox. 4,5 kg.'], dtype=object)

# %%
# Visualizar valores unico sen el campo Nombre_Prod
cantidad_por_subcategoria = dfcompras_2021_2022_V2.groupby(['Nombre_Prod', 'Categoria_Prod'])['Categoria_Prod'].size()
cantidad_por_subcategoria
# Out:
# Nombre_Prod                                      Categoria_Prod
# AJUSTE 31/12/20                                  All                                                                                                 1
# Abrillantador Finish 500 ml                      Droguería, Perfumería, Limpieza, Higiene, Hogar / Droguería / Productos de limpieza                 3
# Abrillantador lavavajillas Ecodoo 500 ml         Droguería, Perfumería, Limpieza, Higiene, Hogar / Droguería / Productos de limpieza                 4
# Acedía grande limpia y entera                    Resto Producto Fresco / Pescados y mariscos / Pescado fresco                                        1
# Aceite caléndula y almendras Piel sana 100 ml    Droguería, Perfumería, Limpieza, Higiene, Hogar / Parafarmacia y cosmética / Cuidado de la piel     3
#                                                                                                                                                     ..
# ...

# %%
cantidad_por_subcategoria = dfcompras_2021_2022_V2['Nombre_Prod'].value_counts()
print(cantidad_por_subcategoria)
# Out:
# Pan integral de espelta El árbol del pan 500 gr                     501
# Pan de cereales con semillas El árbol del pan 500 gr                497
# Pan blanco de trigo El árbol del pan 500 gr                         494
# Envase Veer 33cl                                                    493
# Pan integral de trigo El árbol del pan 500 gr                       492
#                                                                    ...
# Esparrago extra frasco 9-12 Gourmet 110 gr                            1
# Nuez pelada al vacio  Valle de taibilla 100 gr                        1
# Mascarilla FFP2 negra CE 0370 UPMASK pack 20 ud                       1
# Pan integral de trigo y centeno rebanado El árbol del pan 750 gr      1
# Pollo capón deshuesado  Sanchonar aprox. 4,5 kg.                      1
# Name: Nombre_Prod, Length: 4702, dtype: int64

# %%
# Vamos a proceder a limitar la fecha con mes y año

# Primero ordenamos por fecha.
dfcompras_2021_2022_V2.sort_values(by='Fecha_Compra')  

# se define el formato fecha por año y mes porque se requiere promedios mensuales
dfcompras_2021_2022_V2['Fecha_Compra'] = pd.PeriodIndex(dfcompras_2021_2022_V2['Fecha_Compra'], freq='M')
dfcompras_2021_2022_V2
# Out:
#                                             Nombre_Prod  Costo_Compra  \
# 0                                    Manzana royal gala          1.53
# 5                                           Tomate rama          2.31
# 9                         Recambio cepillo suave Yaweco          4.06
# 10                  Recambio cepillo medium hard Yaweco          4.06
# 11    Mini guantes de algodón bio reutilizables Anae...          4.30
# ...                                                 ...           ...
# 4220                                             Pomelo          1.38
# 4230                                        Tomate pera          1.44
# 4234                                      Tomate cherry          2.08
# 4238                                     Cebolla Blanca          0.92
# 4248                                          Mandarina          1.66
#
#      Fecha_Compra     Tipo_Prod Id_Prod_2  \
# 0         2021-12           Eco    000921
# ...

# %%
### Calular el promedio de costo_compra por producto considerando mes y año.

# Convertir 'Fecha_Compra' a tipo datetime y extraer año y mes
# dfcompras_2021_2022_V2['Fecha_Compra'] = pd.to_datetime(dfcompras_2021_2022_V2['Fecha_Compra'])
dfcompras_2021_2022_V2['Año_Compra'] = dfcompras_2021_2022_V2['Fecha_Compra'].dt.year
dfcompras_2021_2022_V2['Mes_Compra'] = dfcompras_2021_2022_V2['Fecha_Compra'].dt.month

# Agrupar por 'Id_Prod_2', 'año' y 'mes' y calcular el promedio de 'Costo_Compra'
promedio_costo_por_producto_mes = dfcompras_2021_2022_V2.groupby(['Id_Prod_2', 'Año_Compra', 'Mes_Compra'])['Costo_Compra'].mean()

# Mostrar resultado
print(promedio_costo_por_producto_mes)
# Out:
# Id_Prod_2  Año_Compra  Mes_Compra
# 000005     2021        1             19.00
# 000008     2021        2              7.44
#                        7              7.44
# 000009     2021        1              5.43
#                        6              5.35
#                                      ...
# 006514     2022        12             7.72
# 006515     2022        12             2.06
# 006516     2022        12             2.06
# 006517     2022        12             2.01
# 006518     2022        12             2.06
# Name: Costo_Compra, Length: 36297, dtype: float64

# %%
# Convertir la serie anterior en DataFrame
promedio_costo_por_producto_mes_df = promedio_costo_por_producto_mes.to_frame().reset_index()
promedio_costo_por_producto_mes_df
# Out:
#       Id_Prod_2  Año_Compra  Mes_Compra  Costo_Compra
# 0        000005        2021           1         19.00
# 1        000008        2021           2          7.44
# 2        000008        2021           7          7.44
# 3        000009        2021           1          5.43
# 4        000009        2021           6          5.35
# ...         ...         ...         ...           ...
# 36292    006514        2022          12          7.72
# 36293    006515        2022          12          2.06
# 36294    006516        2022          12          2.06
# 36295    006517        2022          12          2.01
# 36296    006518        2022          12          2.06
#
# [36297 rows x 4 columns]

# %%
# OBSERRVACION
# Tenemos 36297 registros del df con los promedio de cada producto por fecha y año de compra.
# ESTA VALIDADO

# %%
gg=36297*2
gg
# Out:
# 72594

# %%
# Antes de fusionar ambos dataframe necesitamos eliminar el campo Costo_Compra del df dfcompras_2021_2022_V2,
# porque necesitamos el precio de compra promedio generado en promedio_costo_por_producto_df
dfcompras_2021_2022_V3 = dfcompras_2021_2022_V2.drop('Costo_Compra', axis=1)
dfcompras_2021_2022_V3.head(5)
# Out:
#                                           Nombre_Prod Fecha_Compra  \
# 0                                  Manzana royal gala      2021-12
# 5                                         Tomate rama      2021-12
# 9                       Recambio cepillo suave Yaweco      2021-12
# 10                Recambio cepillo medium hard Yaweco      2021-12
# 11  Mini guantes de algodón bio reutilizables Anae...      2021-12
#
#        Tipo_Prod Id_Prod_2                                       Proveedor  \
# 0            Eco    000921                  (GUMENDI) GUMIEL Y MENDIA S.L.
# 5            Eco    001483                  (GUMENDI) GUMIEL Y MENDIA S.L.
# 9   Convencional    005758  (NATURCOSMETIKA) NATURCOSMETIKA ECOLOGICA S.L.
# 10  Convencional    005753  (NATURCOSMETIKA) NATURCOSMETIKA ECOLOGICA S.L.
# 11           Eco    004514  (NATURCOSMETIKA) NATURCOSMETIKA ECOLOGICA S.L.
#
#                                        Categoria_Prod  Año_Compra  Mes_Compra
# ...

# %%
dfcompras_2021_2022_V3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76018 entries, 0 to 4248
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre_Prod     76018 non-null  object
#  1   Fecha_Compra    76018 non-null  period[M]
#  2   Tipo_Prod       76018 non-null  object
#  3   Id_Prod_2       76018 non-null  object
#  4   Proveedor       76018 non-null  object
#  5   Categoria_Prod  76018 non-null  object
#  6   Año_Compra      76018 non-null  int64
#  7   Mes_Compra      76018 non-null  int64
# dtypes: int64(2), object(5), period[M](1)
# memory usage: 5.2+ MB

# %%
# resetear los índices
dfcompras_2021_2022_V4 = dfcompras_2021_2022_V3.reset_index(drop=True)

# mostrar el dataframe con los índices ordenados
dfcompras_2021_2022_V4
# Out:
#                                              Nombre_Prod Fecha_Compra  \
# 0                                     Manzana royal gala      2021-12
# 1                                            Tomate rama      2021-12
# 2                          Recambio cepillo suave Yaweco      2021-12
# 3                    Recambio cepillo medium hard Yaweco      2021-12
# 4      Mini guantes de algodón bio reutilizables Anae...      2021-12
# ...                                                  ...          ...
# 76013                                             Pomelo      2022-12
# 76014                                        Tomate pera      2022-12
# 76015                                      Tomate cherry      2022-12
# 76016                                     Cebolla Blanca      2022-12
# 76017                                          Mandarina      2022-12
#
#           Tipo_Prod Id_Prod_2  \
# 0               Eco    000921
# 1               Eco    001483
# 2      Convencional    005758
# ...

# %%
dfcompras_2021_2022_V4
# Out:
#                                              Nombre_Prod Fecha_Compra  \
# 0                                     Manzana royal gala      2021-12
# 1                                            Tomate rama      2021-12
# 2                          Recambio cepillo suave Yaweco      2021-12
# 3                    Recambio cepillo medium hard Yaweco      2021-12
# 4      Mini guantes de algodón bio reutilizables Anae...      2021-12
# ...                                                  ...          ...
# 76013                                             Pomelo      2022-12
# 76014                                        Tomate pera      2022-12
# 76015                                      Tomate cherry      2022-12
# 76016                                     Cebolla Blanca      2022-12
# 76017                                          Mandarina      2022-12
#
#           Tipo_Prod Id_Prod_2  \
# 0               Eco    000921
# 1               Eco    001483
# 2      Convencional    005758
# ...

# %%
## FUSIONAR LOS DOS DATAFRAME 
# renombrar el campo "Id_Prod_2" en el dataframe "dfcompras_2021_2022_V2"
# dfcompras_2021_2022_V3 = dfcompras_2021_2022_V3.rename(columns={'Id_Prod_2': 'Id_Producto'})

# fusionar los dataframes priorizando "promedio_costo_por_producto_mes_df"
# merged_df = pd.merge(promedio_costo_por_producto_mes_df, dfcompras_2021_2022_V3, on='Id_Prod_2', how='left')

## merged_df = pd.merge(promedio_costo_por_producto_mes_df, dfcompras_2021_2022_V3[['Id_Prod_2', 'Año_Compra', 'Mes_Compra', 'Nombre_Prod', 'Tipo_Prod', 'Proveedor', 'Categoria_Prod']], on=['Id_Prod_2', 'Año_Compra', 'Mes_Compra'], how='left')
# Realizar el merge
merged_df = pd.merge(promedio_costo_por_producto_mes_df, dfcompras_2021_2022_V4[['Id_Prod_2', 'Fecha_Compra','Año_Compra', 'Mes_Compra', 'Nombre_Prod', 'Tipo_Prod', 'Proveedor', 'Categoria_Prod']], on=['Id_Prod_2', 'Año_Compra', 'Mes_Compra'], how='left')



# mostrar el dataframe fusionado
merged_df.head(20022)
# Out:
#       Id_Prod_2  Año_Compra  Mes_Compra  Costo_Compra Fecha_Compra  \
# 0        000005        2021           1         19.00      2021-01
# 1        000008        2021           2          7.44      2021-02
# 2        000008        2021           2          7.44      2021-02
# 3        000008        2021           7          7.44      2021-07
# 4        000009        2021           1          5.43      2021-01
# ...         ...         ...         ...           ...          ...
# 20017    001167        2022           4         22.59      2022-04
# 20018    001167        2022           5         22.59      2022-05
# 20019    001167        2022           5         22.59      2022-05
# 20020    001167        2022           5         22.59      2022-05
# 20021    001167        2022           6         22.59      2022-06
#
#                                             Nombre_Prod     Tipo_Prod  \
# 0                         Acedía grande limpia y entera  Convencional
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76018 entries, 0 to 76017
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id_Prod_2       76018 non-null  object
#  1   Año_Compra      76018 non-null  int64
#  2   Mes_Compra      76018 non-null  int64
#  3   Costo_Compra    76018 non-null  float64
#  4   Fecha_Compra    76018 non-null  period[M]
#  5   Nombre_Prod     76018 non-null  object
#  6   Tipo_Prod       76018 non-null  object
#  7   Proveedor       76018 non-null  object
#  8   Categoria_Prod  76018 non-null  object
# dtypes: float64(1), int64(2), object(5), period[M](1)
# memory usage: 5.8+ MB

# %%
# Consultar un registro especifico para copararlo con el registro en promedio_costo_por_producto_mes_df
merged_df[merged_df.Nombre_Prod=="Manzana royal gala"]
# Out:
#       Id_Prod_2  Año_Compra  Mes_Compra  Costo_Compra Fecha_Compra  \
# 13498    000921        2021           1      2.162000      2021-01
# 13499    000921        2021           1      2.162000      2021-01
# 13500    000921        2021           1      2.162000      2021-01
# 13501    000921        2021           1      2.162000      2021-01
# 13502    000921        2021           1      2.162000      2021-01
# ...         ...         ...         ...           ...          ...
# 13710    000921        2022          12      1.725294      2022-12
# 13711    000921        2022          12      1.725294      2022-12
# 13712    000921        2022          12      1.725294      2022-12
# 13713    000921        2022          12      1.725294      2022-12
# 13714    000921        2022          12      1.725294      2022-12
#
#               Nombre_Prod Tipo_Prod                       Proveedor  \
# 13498  Manzana royal gala       Eco  (GUMENDI) GUMIEL Y MENDIA S.L.
# ...

# %%
# Consultar el mismo regstro en promedio_costo_por_producto_mes_df para verificar si existe consistencia en los datos
# Vamos a considerar el campo Id_Prod_2 para filtar el producto
promedio_costo_por_producto_mes_df[promedio_costo_por_producto_mes_df.Id_Prod_2=="000921"]
# Out:
#      Id_Prod_2  Año_Compra  Mes_Compra  Costo_Compra
# 5364    000921        2021           1      2.162000
# 5365    000921        2021           2      2.083333
# 5366    000921        2021           3      2.181667
# 5367    000921        2021           4      2.083636
# 5368    000921        2021           5      2.200000
# 5369    000921        2021           6      2.155000
# 5370    000921        2021           7      2.040000
# 5371    000921        2021           8      2.107500
# 5372    000921        2021           9      1.763077
# 5373    000921        2021          10      1.720000
# 5374    000921        2021          11      1.593333
# 5375    000921        2021          12      1.541111
# 5376    000921        2022           1      1.770000
# 5377    000921        2022           2      1.504000
# 5378    000921        2022           3      1.643889
# 5379    000921        2022           4      1.815455
# 5380    000921        2022           5      1.639091
# ...

# %%
# Generar un nuevo dataframe con registros únicos en base a las columnas Id_Prod_2, Año_Compra y Mes_Compra
nuevo_df = merged_df.drop_duplicates(subset=['Id_Prod_2', 'Año_Compra', 'Mes_Compra'])

# Imprimir el nuevo dataframe
nuevo_df
# Out:
#       Id_Prod_2  Año_Compra  Mes_Compra  Costo_Compra Fecha_Compra  \
# 0        000005        2021           1         19.00      2021-01
# 1        000008        2021           2          7.44      2021-02
# 3        000008        2021           7          7.44      2021-07
# 4        000009        2021           1          5.43      2021-01
# 6        000009        2021           6          5.35      2021-06
# ...         ...         ...         ...           ...          ...
# 76013    006514        2022          12          7.72      2022-12
# 76014    006515        2022          12          2.06      2022-12
# 76015    006516        2022          12          2.06      2022-12
# 76016    006517        2022          12          2.01      2022-12
# 76017    006518        2022          12          2.06      2022-12
#
#                                          Nombre_Prod     Tipo_Prod  \
# 0                      Acedía grande limpia y entera  Convencional
# ...

# %%
# Ordenar el nuevo dataframe en base a las columnas  Año_Compra y Mes_Compra
nuevo_df_ordenado = nuevo_df.sort_values(['Año_Compra', 'Mes_Compra'])

# Imprimir el nuevo dataframe ordenado
nuevo_df_ordenado
# Out:
#       Id_Prod_2  Año_Compra  Mes_Compra  Costo_Compra Fecha_Compra  \
# 0        000005        2021           1         19.00      2021-01
# 4        000009        2021           1          5.43      2021-01
# 22       000013        2021           1          2.91      2021-01
# 35       000018        2021           1         12.94      2021-01
# 50       000020        2021           1         22.95      2021-01
# ...         ...         ...         ...           ...          ...
# 76013    006514        2022          12          7.72      2022-12
# 76014    006515        2022          12          2.06      2022-12
# 76015    006516        2022          12          2.06      2022-12
# 76016    006517        2022          12          2.01      2022-12
# 76017    006518        2022          12          2.06      2022-12
#
#                                           Nombre_Prod     Tipo_Prod  \
# 0                       Acedía grande limpia y entera  Convencional
# ...

# %%
# Resetear el índice del dataframe ordenado
nuevo_df_ordenado_reset = nuevo_df_ordenado.reset_index(drop=True)

# Imprimir el dataframe reseteado
nuevo_df_ordenado_reset
# Out:
#       Id_Prod_2  Año_Compra  Mes_Compra  Costo_Compra Fecha_Compra  \
# 0        000005        2021           1         19.00      2021-01
# 1        000009        2021           1          5.43      2021-01
# 2        000013        2021           1          2.91      2021-01
# 3        000018        2021           1         12.94      2021-01
# 4        000020        2021           1         22.95      2021-01
# ...         ...         ...         ...           ...          ...
# 36292    006514        2022          12          7.72      2022-12
# 36293    006515        2022          12          2.06      2022-12
# 36294    006516        2022          12          2.06      2022-12
# 36295    006517        2022          12          2.01      2022-12
# 36296    006518        2022          12          2.06      2022-12
#
#                                           Nombre_Prod     Tipo_Prod  \
# 0                       Acedía grande limpia y entera  Convencional
# ...

# %%
# CONCLUSION
# Se obtiene un dataframe con 36297 registros de COMPRAS para ser utilizado en el análisis.
# Renombramos el dataframe obtenido
dfosa_compras=nuevo_df_ordenado
dfosa_compras
# Out:
#       Id_Prod_2  Año_Compra  Mes_Compra  Costo_Compra Fecha_Compra  \
# 0        000005        2021           1         19.00      2021-01
# 4        000009        2021           1          5.43      2021-01
# 22       000013        2021           1          2.91      2021-01
# 35       000018        2021           1         12.94      2021-01
# 50       000020        2021           1         22.95      2021-01
# ...         ...         ...         ...           ...          ...
# 76013    006514        2022          12          7.72      2022-12
# 76014    006515        2022          12          2.06      2022-12
# 76015    006516        2022          12          2.06      2022-12
# 76016    006517        2022          12          2.01      2022-12
# 76017    006518        2022          12          2.06      2022-12
#
#                                           Nombre_Prod     Tipo_Prod  \
# 0                       Acedía grande limpia y entera  Convencional
# ...

# %%
dfosa_compras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36297 entries, 0 to 76017
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id_Prod_2       36297 non-null  object
#  1   Año_Compra      36297 non-null  int64
#  2   Mes_Compra      36297 non-null  int64
#  3   Costo_Compra    36297 non-null  float64
#  4   Fecha_Compra    36297 non-null  period[M]
#  5   Nombre_Prod     36297 non-null  object
#  6   Tipo_Prod       36297 non-null  object
#  7   Proveedor       36297 non-null  object
#  8   Categoria_Prod  36297 non-null  object
# dtypes: float64(1), int64(2), object(5), period[M](1)
# memory usage: 2.8+ MB

# %%
# Verificar valores nulos
dfosa_compras.isnull().sum()
# Out:
# Id_Prod_2         0
# Año_Compra        0
# Mes_Compra        0
# Costo_Compra      0
# Fecha_Compra      0
# Nombre_Prod       0
# Tipo_Prod         0
# Proveedor         0
# Categoria_Prod    0
# dtype: int64

# %%
## Visualizar los atributos de dfosa_ventas y dfosa_compras para concadenarlos
dfosa_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93720 entries, 0 to 93719
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id_Prod_2    93720 non-null  object
#  1   Nom_Prod     93720 non-null  object
#  2   Cant_Prod    93720 non-null  float64
#  3   Precio_Prod  93720 non-null  float64
#  4   Fecha_Venta  93720 non-null  period[M]
#  5   Año_Venta    93720 non-null  int64
#  6   Mes_Venta    93720 non-null  int64
# dtypes: float64(2), int64(2), object(2), period[M](1)
# memory usage: 5.0+ MB

# %%
dfosa_compras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36297 entries, 0 to 76017
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id_Prod_2       36297 non-null  object
#  1   Año_Compra      36297 non-null  int64
#  2   Mes_Compra      36297 non-null  int64
#  3   Costo_Compra    36297 non-null  float64
#  4   Fecha_Compra    36297 non-null  period[M]
#  5   Nombre_Prod     36297 non-null  object
#  6   Tipo_Prod       36297 non-null  object
#  7   Proveedor       36297 non-null  object
#  8   Categoria_Prod  36297 non-null  object
# dtypes: float64(1), int64(2), object(5), period[M](1)
# memory usage: 2.8+ MB

# %%
# Renombrar el campo Cant_Prod por Cant_Prod_Venta para señalar que pertenece al reporte de ventas
dfosa_ventas.rename(columns={'Cant_Prod':'Cant_Prod_Venta'}, inplace=True)

# %%
dfosa_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93720 entries, 0 to 93719
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id_Prod_2        93720 non-null  object
#  1   Nom_Prod         93720 non-null  object
#  2   Cant_Prod_Venta  93720 non-null  float64
#  3   Precio_Prod      93720 non-null  float64
#  4   Fecha_Venta      93720 non-null  period[M]
#  5   Año_Venta        93720 non-null  int64
#  6   Mes_Venta        93720 non-null  int64
# dtypes: float64(2), int64(2), object(2), period[M](1)
# memory usage: 5.0+ MB

# %%
# Queda pendiente concatenar dfosa_ventas y dfosa_compras pero priorizando el numero de registros de COMPRAS.
# Hay que analizar si debeos comprimar más el archivo de Ventas.

# %%
# Renombrar el campo Nom_Prod por Nombre_Prod en ventas para que coincida con la misma columna de compras y asi hacer el merge
dfosa_ventas.rename(columns={'Nom_Prod':'Nombre_Prod'}, inplace=True)

# %%
#igual se hace con la fecha
dfosa_ventas.rename(columns={'Fecha_Venta':'Fecha'}, inplace=True)
dfosa_compras.rename(columns={'Fecha_Compra':'Fecha'}, inplace=True)

# %% [markdown]
# ### DATOS CONSOLIDADOS EN UN SOLO DATASET

# %%
Osa_df = dfosa_compras.merge(dfosa_ventas, on=['Id_Prod_2', 'Nombre_Prod', 'Fecha'], how='inner')
#merged_df = merged_df.drop_duplicates(subset=['Id_Prod_2', 'Año_C', 'Mes_Compra'])
Osa_df.head()
#lo convertimos a csv para continuar con el analisis en otro Notebook
Osa_df.to_csv('Osa_df.csv', header=True, index=False)

# %% [markdown]
# ### ir al Dataset EDA_Osa.ipynb
